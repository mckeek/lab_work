# %%
from nltk.probability import ELEProbDist, FreqDist
from nltk import NaiveBayesClassifier
from sklearn.model_selection import train_test_split
from collections import defaultdict
from nltk.tokenize import word_tokenize
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize.api import TokenizerI
from nltk.tokenize.util import align_tokens

# import punkt
from nltk.tokenize import TreebankWordTokenizer
import nltk.tokenize.punkt
from nltk.probability import FreqDist

# %%
SWdf = pd.read_csv('NLPout.csv')

# %%
d = {"TARKIN": "RED_LEADER", "WEDGE": "RED_LEADER", "RED LEADER": "RED_LEADER","BEN'S VOICE":"BEN","LUKE'S VOICE":'LUKE',"HAN'S VOICE":"HAN", "FIRST TROOPER":"TROOPER", "TROOPER VOICE":"TROOPER"}
SWdf = SWdf.replace(d)
len(d)
# Out:
# 8

# %%
chars = [ 'LEIA','TROOPER','LUKE','HAN','THREEPIO','VADER','WEDGE','TARKIN','RED_LEADER','OFFICER','JABBA','BIGGS']
#'LUKE','HAN','THREEPIO',
ccorpus = SWdf.loc[SWdf['char'].isin(chars)]
ccorpus = ccorpus[['text','char']]

trainx, testx = train_test_split(ccorpus, test_size=0.2)

# %%
trainy = trainx.apply(tuple, axis=1)
len(trainy)
# Out:
# 620

# %%
train = []
for (words, cclass) in trainy:
    words_filtered = [e.lower() for e in words.split() if len(e) >= 3]
    #print(words_filtered)
    train.append((words_filtered, cclass))
len(train)
train
# Out:
# [(['uh,',
#    'uh,',
#    'negative.',
#    'had',
#    'reactor',
#    'leak',
#    'here',
#    'now.',
#    'give',
#    'few',
#    'minutes',
#    'lock',
#    'down.',
#    'large',
#    'leak...',
#    'very',
#    'dangerous.'],
#   'HAN'),
#  (['several',
#    'fighters',
#    'have',
#    'broken',
#    'off',
#    'from',
#    'the',
#    'main',
#    'group.',
#    'come',
#    'with',
#    'me!'],
#   'VADER'),
#  (["they're",
#    'going',
#    'execute',
#    'her.',
#    'look,',
#    'few',
#    'minutes',
#    'ago',
#    'you',
#    'said',
#    'you',
#    "didn't",
#    'want',
#    'just',
#    'wait',
#    'here',
#    'captured.',
#    'now',
#    'all',
#    'you',
#    'want',
#    'stay.'],
#   'LUKE'),
#  (['wish', "i'd", 'known', 'him.'], 'LUKE'),
#  (['boring',
#    'conversation',
#    'anyway.',
#    '(yelling',
#    'down',
#    'the',
#    'hall)',
#    'luke!',
#    "we're",
#    'going',
#    'have',
#    'company!'],
#   'HAN'),
#  (['(over', 'speaker)', 'rendezvous', 'mark', 'six', 'point', 'one.'],
#   'RED_LEADER'),
#  (['but', "there's", 'gotta', 'something', 'you', 'can', 'do!'], 'LUKE'),
#  (['luke,', 'luke,', 'grab', 'hold', 'this.'], 'LEIA'),
#  (['what', 'it?'], 'LUKE'),
#  (['no!'], 'LUKE'),
#  (['listen,',
#    'why',
#    "don't",
#    'you',
#    'wait',
#    'out',
#    'the',
#    'speeder.',
#    "don't",
#    'want',
#    'any',
#    'trouble.'],
#   'LUKE'),
#  (['(pointing', 'luke)', "he's", 'the', 'brains,', 'sweetheart.'], 'HAN'),
#  (['look,',
#    'your',
#    'worshipfulness,',
#    "let's",
#    'get',
#    'one',
#    'thing',
#    'straight!',
#    'take',
#    'orders',
#    'from',
#    'one',
#    'person!',
#    'me!'],
#   'HAN'),
#  (['not',
#    'your',
#    'life!',
#    'that',
#    'little',
#    'droid',
#    'and',
#    'have',
#    'been',
#    'through',
#    'lot',
#    'together.',
#    '(to',
#    'artoo)',
#    'you',
#    'okay,',
#    'artoo?'],
#   'LUKE'),
#  (['the',
#    'technical',
#    'readouts',
#    'that',
#    'battle',
#    'station.',
#    'only',
#    'hope',
#    'that',
#    'when',
#    'the',
#    'data',
#    'analyzed,',
#    'weakness',
#    'can',
#    'found.',
#    "it's",
#    'not',
#    'over',
#    'yet!'],
#   'LEIA'),
#  (['what',
#    'makes',
#    'you',
#    'think',
#    'there',
#    'are',
#    'settlements',
#    'over',
#    'there?'],
#   'THREEPIO'),
#  (['the',
#    'droid',
#    'belongs',
#    'her.',
#    "she's",
#    'the',
#    'one',
#    'the',
#    'message...',
#    "we've",
#    'got',
#    'help',
#    'her.'],
#   'LUKE'),
#  (["don't", 'get', 'technical', 'with', 'me.'], 'THREEPIO'),
#  (["that's",
#    'right,',
#    'yeah!',
#    'got',
#    'some',
#    'old',
#    'debts',
#    "i've",
#    'got',
#    'pay',
#    'off',
#    'with',
#    'this',
#    'stuff.',
#    'even',
#    "didn't,",
#    'you',
#    "don't",
#    'think',
#    "i'd",
#    'fool',
#    'enough',
#    'stick',
#    'around',
#    'here,',
#    'you?',
#    'why',
#    "don't",
#    'you',
#    'come',
#    'with',
#    'us?',
#    "you're",
#    'pretty',
#    'good',
#    'fight.',
#    'could',
#    'use',
#    'you.'],
#   'HAN'),
#  (['what', 'are', 'you', 'doing', 'hiding', 'there?'], 'LUKE'),
#  (['grab', 'him!'], 'LEIA'),
#  (['here...'], 'VADER'),
#  (['hey...',
#    'hey,',
#    'open',
#    'the',
#    'pressure',
#    'maintenance',
#    'hatch',
#    'unit',
#    'number...',
#    'where',
#    'are',
#    'we?'],
#   'LUKE'),
#  (['will',
#    'you',
#    'forget',
#    'it?',
#    'already',
#    'tried',
#    'it.',
#    "it's",
#    'magnetically',
#    'sealed!'],
#   'LUKE'),
#  (['(under', 'his', 'breath)', 'good...'], 'LUKE'),
#  (['where?'], 'HAN'),
#  (["it's", 'all', 'lot', 'simple', 'tricks', 'and', 'nonsense.'], 'HAN'),
#  (['(to', 'luke)', 'come', 'on!'], 'HAN'),
#  (["i'm", 'the', 'leader.'], 'VADER'),
#  (['(sarcastically)',
#    'maybe',
#    "you'd",
#    'like',
#    'back',
#    'your',
#    'cell,',
#    'your',
#    'highness.'],
#   'HAN'),
#  (['well,',
#    "there's",
#    'bright',
#    'center',
#    'the',
#    'universe,',
#    "you're",
#    'the',
#    'planet',
#    'that',
#    "it's",
#    'farthest',
#    'from.'],
#   'LUKE'),
#  (['there.',
#    'you',
#    'see',
#    'lord',
#    'vader,',
#    'she',
#    'can',
#    'reasonable.',
#    '(addressing',
#    'motti)',
#    'continue',
#    'with',
#    'the',
#    'operation.',
#    'you',
#    'may',
#    'fire',
#    'when',
#    'ready.'],
#   'RED_LEADER'),
#  (["i'm", 'afraid', "i'm", 'not', 'quite', 'sure,', 'sir.'], 'THREEPIO'),
#  (['the', 'force?'], 'LUKE'),
#  (['what', 'happened?'], 'LUKE'),
#  (['you',
#    'know,',
#    'even',
#    'get',
#    'boarded',
#    'sometimes,',
#    'jabba.',
#    'had',
#    'choice,',
#    'but',
#    "i've",
#    'got',
#    'charter',
#    'now',
#    'and',
#    'can',
#    'pay',
#    'you',
#    'back,',
#    'plus',
#    'little',
#    'extra.',
#    'just',
#    'need',
#    'some',
#    'more',
#    'time.'],
#   'HAN'),
#  (["it's",
#    'too',
#    'dangerous',
#    'with',
#    'all',
#    'the',
#    'sandpeople',
#    'around.',
#    "we'll",
#    'have',
#    'wait',
#    'until',
#    'morning.'],
#   'LUKE'),
#  (['master',
#    'luke',
#    'here',
#    'your',
#    'rightful',
#    'owner.',
#    "we'll",
#    'have',
#    'more',
#    'this',
#    'obi-wan',
#    'kenobi',
#    'jibberish...',
#    'and',
#    "don't",
#    'talk',
#    'about',
#    'your',
#    'mission,',
#    'either.',
#    "you're",
#    'fortunate',
#    "doesn't",
#    'blast',
#    'you',
#    'into',
#    'million',
#    'pieces',
#    'right',
#    'here.'],
#   'THREEPIO'),
#  (['ben?', 'ben', 'kenobi!', 'boy,', 'glad', 'see', 'you!'], 'LUKE'),
#  (['can',
#    'just',
#    'avoid',
#    'any',
#    'more',
#    'female',
#    'advice,',
#    'ought',
#    'able',
#    'get',
#    'out',
#    'here.'],
#   'HAN'),
#  (['what?'], 'HAN'),
#  (["we've",
#    'got',
#    'find',
#    'out',
#    'which',
#    'cell',
#    'this',
#    'princess',
#    'yours',
#    'in.',
#    'here',
#    'is...',
#    'cell',
#    'twenty-one-eight-seven.',
#    'you',
#    'get',
#    'her.',
#    "i'll",
#    'hold',
#    'them',
#    'here.'],
#   'HAN'),
#  (['(over', 'headset)', 'red', 'six...'], 'RED_LEADER'),
#  (["we'll",
#    'have',
#    'destroy',
#    'them',
#    'ship',
#    'ship.',
#    'get',
#    'the',
#    'crews',
#    'their',
#    'fighters.'],
#   'VADER'),
#  (['they',
#    "aren't",
#    'here!',
#    'something',
#    'must',
#    'have',
#    'happened',
#    'them.',
#    'see',
#    "they've",
#    'been',
#    'captured.'],
#   'THREEPIO'),
#  (['followed', 'us!'], 'LUKE'),
#  (['are', 'you', 'all', 'right?', "what's", 'wrong?'], 'LUKE'),
#  (['(over', 'comlink)', 'yes', 'sir?'], 'THREEPIO'),
#  (['yeah,', 'great', 'getting', 'into', 'trouble.'], 'HAN'),
#  (["that's", 'your', 'imagination.'], 'HAN'),
#  (['yes,', 'sir.'], 'OFFICER'),
#  (["what's", 'this?'], 'LUKE'),
#  (['better!'], 'HAN'),
#  (['no!'], 'LEIA'),
#  (['all', 'right.'], 'TROOPER'),
#  (['last!', 'where', 'have', 'you', 'been?'], 'THREEPIO'),
#  (['hold', 'tight!'], 'RED_LEADER'),
#  (['(to', 'luke', 'and', 'leia)', 'get', 'back', 'the', 'ship!'], 'HAN'),
#  (['something',
#    'just',
#    'moves',
#    'past',
#    'leg!',
#    'look!',
#    'did',
#    'you',
#    'see',
#    'that?'],
#   'LUKE'),
#  (['they', 'have', 'just', 'made', 'the', 'jump', 'into', 'hyperspace.'],
#   'VADER'),
#  (['find', 'your', 'lack', 'faith', 'disturbing.'], 'VADER'),
#  (["i'm",
#    'sorry,',
#    'sir,',
#    'but',
#    'appears',
#    'have',
#    'picked',
#    'slight',
#    'flutter.'],
#   'THREEPIO'),
#  (['what', 'about', 'that', 'one?'], 'LUKE'),
#  (['wait,',
#    "there's",
#    'something',
#    'dead',
#    'ahead',
#    'the',
#    'scanner.',
#    'looks',
#    'like',
#    'our',
#    'droid...',
#    'hit',
#    'the',
#    'accelerator.'],
#   'LUKE'),
#  (["you'll", 'get', 'it!'], 'LUKE'),
#  (['lord',
#    'vader,',
#    'should',
#    'have',
#    'known.',
#    'only',
#    'you',
#    'could',
#    'bold.',
#    'the',
#    'imperial',
#    'senate',
#    'will',
#    'not',
#    'sit',
#    'for',
#    'this,',
#    'when',
#    'they',
#    'hear',
#    "you've",
#    'attacked',
#    'diplomatic...'],
#   'LEIA'),
#  (['watch',
#    'yourself!',
#    "there's",
#    'lot',
#    'fire',
#    'coming',
#    'from',
#    'the',
#    'right',
#    'side',
#    'that',
#    'deflection',
#    'tower.'],
#   'RED_LEADER'),
#  (['but', "they're", 'going', 'kill', 'her!'], 'LUKE'),
#  (['no,', "don't", 'think', 'likes', 'you', 'all.'], 'THREEPIO'),
#  (['no,', "he's", 'not', 'going', 'try', 'anything.'], 'LUKE'),
#  (['well,',
#    'see',
#    'what',
#    'you',
#    'can',
#    'with',
#    'him.',
#    "i'll",
#    'right',
#    'back.'],
#   'LUKE'),
#  (['princess?', "what's", 'going', 'on?'], 'HAN'),
#  (['uncle', 'owen...'], 'LUKE'),
#  (['hurry!'], 'THREEPIO'),
#  (['hello,', 'sir.'], 'THREEPIO'),
#  (['course',
#    'got',
#    'it.',
#    'signed',
#    'aboard',
#    'the',
#    'rand',
#    'ecliptic',
#    'last',
#    'week.',
#    'first',
#    'mate',
#    'biggs',
#    'darklighter',
#    'your',
#    'service...',
#    '(he',
#    'salutes)',
#    '...i',
#    'just',
#    'came',
#    'say',
#    'good-bye',
#    'all',
#    'you',
#    'unfortunate',
#    'landlocked',
#    'simpletons.'],
#   'BIGGS'),
#  (['hey,', 'luke...', 'may', 'the', 'force', 'with', 'you!'], 'HAN'),
#  (['tremor',
#    'the',
#    'force.',
#    'the',
#    'last',
#    'time',
#    'felt',
#    'was',
#    'the',
#    'presence',
#    'old',
#    'master.'],
#   'VADER'),
#  (['how',
#    'did',
#    'get',
#    'into',
#    'this',
#    'mess?',
#    'really',
#    "don't",
#    'know',
#    'how.',
#    'seem',
#    'made',
#    'suffer.',
#    "it's",
#    'our',
#    'lot',
#    'life.'],
#   'THREEPIO'),
#  (['(over', 'headset)', 'stay', 'there...'], 'RED_LEADER'),
#  (['(quickly)',
#    'sir',
#    'not',
#    'environment',
#    'such',
#    'this',
#    "that's",
#    'why',
#    "i've",
#    'also',
#    'been',
#    'programmed',
#    'for',
#    'over',
#    'thirty',
#    'secondary',
#    'functions',
#    'that...'],
#   'THREEPIO'),
#  (['threepio!', 'come', 'in,', 'threepio!', 'threepio!'], 'LUKE'),
#  (['(to',
#    'artoo)',
#    'artoo...',
#    'that,',
#    'that',
#    "stabilizer's",
#    'broken',
#    'loose',
#    'again!',
#    'see',
#    'you',
#    "can't",
#    'lock',
#    'down!'],
#   'LUKE'),
#  (['okay,', "let's", 'go.'], 'LUKE'),
#  (['look', 'out!', "he's", 'loose!'], 'HAN'),
#  (['keep',
#    'your',
#    'visual',
#    'scanning.',
#    'with',
#    'all',
#    'this',
#    'jamming,',
#    "they'll",
#    'top',
#    'you',
#    'before',
#    'your',
#    'scope',
#    'can',
#    'pick',
#    'them',
#    'up.'],
#   'RED_LEADER'),
#  (['no,', "i'm", 'leaving', 'the', 'morning...'], 'BIGGS'),
#  (['seventeen',
#    'thousand!',
#    'those',
#    'guys',
#    'must',
#    'really',
#    'desperate.',
#    'this',
#    'could',
#    'really',
#    'save',
#    'neck.',
#    'get',
#    'back',
#    'the',
#    'ship',
#    'and',
#    'get',
#    'her',
#    'ready.'],
#   'HAN'),
#  (['hurry,',
#    'luke,',
#    "they're",
#    'coming',
#    'much',
#    'faster',
#    'this',
#    'time.',
#    "can't",
#    'hold',
#    'them!'],
#   'BIGGS'),
#  (['these', 'are', 'not', 'the', 'droids', "we're", 'looking', 'for.'],
#   'TROOPER'),
#  (['(to',
#    'artoo)',
#    'now,',
#    "don't",
#    'you',
#    'forget',
#    'this!',
#    'why',
#    'should',
#    'stick',
#    'neck',
#    'out',
#    'for',
#    'you',
#    'quite',
#    'beyond',
#    'capacity!'],
#   'THREEPIO'),
#  (['secure', 'this', 'area', 'until', 'the', 'alert', 'canceled.'], 'OFFICER'),
#  (['with',
#    'all',
#    "we've",
#    'been',
#    'through,',
#    'sometimes',
#    "i'm",
#    'amazed',
#    "we're",
#    'good',
#    'condition',
#    'are,',
#    'what',
#    'with',
#    'the',
#    'rebellion',
#    'and',
#    'all.'],
#   'THREEPIO'),
#  (['see,', 'sir.'], 'THREEPIO'),
#  (['there', 'she', 'is!', 'set', 'for', 'stun!'], 'TROOPER'),
#  (["he's", 'tight,', "can't", 'shake', 'him...', "can't", 'shake', 'him.'],
#   'BIGGS'),
#  (['move', 'along.', 'move', 'along.'], 'TROOPER'),
#  (['(over', 'comlink)', 'threepio,', "we're", 'all', 'right!'], 'LUKE'),
#  (['luke!'], 'LEIA'),
#  (['(laughing)', "that's", 'it!', 'did', 'it!'], 'LUKE'),
#  (['almost',
#    'forgot.',
#    "there's",
#    'battle',
#    'going',
#    'on!',
#    'right',
#    'here',
#    'our',
#    'system.',
#    'come',
#    'and',
#    'look!'],
#   'LUKE'),
#  (['you', 'think', "they'll", 'melt', 'down?'], 'THREEPIO'),
#  (['her',
#    'resistance',
#    'the',
#    'mind',
#    'probe',
#    'considerable.',
#    'will',
#    'some',
#    'time',
#    'before',
#    'can',
#    'extract',
#    'any',
#    'information',
#    'from',
#    'her.'],
#   'VADER'),
#  (['perhaps', 'she', 'would', 'respond', 'alternative', 'form', 'persuasion.'],
#   'RED_LEADER'),
#  (['you',
#    "don't",
#    'mind',
#    'saying',
#    'so,',
#    'sir,',
#    'think',
#    'you',
#    'should',
#    'deactivate',
#    'the',
#    'little',
#    'fugitive',
#    'until',
#    "you've",
#    'gotten',
#    'him',
#    'back',
#    'your',
#    'workshop.'],
#   'THREEPIO'),
#  (['(over', 'headset)', 'hold', 'on!'], 'RED_LEADER'),
#  (['but',
#    "didn't",
#    'know',
#    'she',
#    'was',
#    'here.',
#    'look,',
#    'will',
#    'you',
#    'just',
#    'find',
#    'way',
#    'back',
#    'into',
#    'the',
#    'detention',
#    'block?'],
#   'LUKE'),
#  (['but', 'what', 'this', 'obi-wan', 'comes', 'looking', 'for', 'him?'],
#   'LUKE'),
#  (['well,',
#    'anything',
#    'would',
#    'better',
#    'than',
#    'just',
#    'hanging',
#    'around',
#    'waiting',
#    'for',
#    'him',
#    'pick',
#    'up...'],
#   'HAN'),
#  (['thank', 'you,', 'sir.', "i'll", 'try.'], 'LUKE'),
#  (["what's", 'that', 'flashing?'], 'LUKE'),
#  (["don't", 'like', 'the', 'look', 'this.'], 'THREEPIO'),
#  (["i'm", 'not', 'going', 'anywhere.'], 'HAN'),
#  (["don't",
#    'think',
#    'so,',
#    'sir.',
#    "i'm",
#    'only',
#    'droid',
#    'and',
#    'not',
#    'very',
#    'knowledgeable',
#    'about',
#    'such',
#    'things.',
#    'not',
#    'this',
#    'planet,',
#    'anyways.',
#    'matter',
#    'fact,',
#    "i'm",
#    'not',
#    'even',
#    'sure',
#    'which',
#    'planet',
#    "i'm",
#    'on.'],
#   'THREEPIO'),
#  (['look', 'him.', "he's", 'headed', 'for', 'that', 'small', 'moon.'], 'LUKE'),
#  (['(getting',
#    'nervous)',
#    'uh...',
#    'had',
#    'slight',
#    'weapons',
#    'malfunction.',
#    'but,',
#    'uh,',
#    "everything's",
#    'perfectly',
#    'all',
#    'right',
#    'now.',
#    "we're",
#    'fine.',
#    "we're",
#    'all',
#    'fine',
#    'here,',
#    'now,',
#    'thank',
#    'you.',
#    'how',
#    'are',
#    'you?'],
#   'HAN'),
#  (["don't", 'shoot!', "don't", 'shoot!', 'will', 'this', 'never', 'end?'],
#   'THREEPIO'),
#  (["i've",
#    'outrun',
#    'imperial',
#    'starships,',
#    'not',
#    'the',
#    'local',
#    'bulk-cruisers,',
#    'mind',
#    'you.',
#    "i'm",
#    'talking',
#    'about',
#    'the',
#    'big',
#    'corellian',
#    'ships',
#    'now.',
#    "she's",
#    'fast',
#    'enough',
#    'for',
#    'you,',
#    'old',
#    'man.',
#    "what's",
#    'the',
#    'cargo?'],
#   'HAN'),
#  (["i'm",
#    'afraid',
#    "i'm",
#    'not',
#    'quite',
#    'sure,',
#    'sir.',
#    'says',
#    'found',
#    'her",',
#    'and',
#    'keeps',
#    'repeating,',
#    '"she\'s',
#    'here."'],
#   'THREEPIO'),
#  (['okay.', 'now,', "i'm", 'going', 'put', 'these', 'you.'], 'LUKE'),
#  (['but', 'there', 'was', 'lot', 'firing', 'earlier...'], 'LUKE'),
#  (['chewie!', 'come', 'here!'], 'HAN'),
#  (['(mock',
#    'surprise)',
#    'han,',
#    'why',
#    "you're",
#    'the',
#    'best',
#    'smuggler',
#    'the',
#    'business.',
#    "you're",
#    'too',
#    'valuable',
#    'fry.',
#    'was',
#    'only',
#    'relaying',
#    'concern',
#    'your',
#    'delays.',
#    "wasn't",
#    'going',
#    'blast',
#    'you.'],
#   'JABBA'),
#  (['(brightening)',
#    'sure.',
#    'needs',
#    'you.',
#    "he'd",
#    'probably',
#    'only',
#    'deactivate',
#    'you',
#    'for',
#    'day',
#    'so...'],
#   'LUKE'),
#  (['stand',
#    'by,',
#    'chewie,',
#    'here',
#    'go.',
#    'cut',
#    'the',
#    'sublight',
#    'engines.'],
#   'HAN'),
#  (['yes,', "i'll", 'bet', 'you', 'have.'], 'HAN'),
#  (["he's", 'going', 'pull', 'all', 'apart.'], 'LUKE'),
#  (['use', 'the', 'comlink?', 'oh,', 'my!', 'forgot', 'turned', 'off!'],
#   'THREEPIO'),
#  (['oh,', 'no!', "we've", 'got', 'something.'], 'LUKE'),
#  (['and,',
#    'now',
#    'your',
#    'highness,',
#    'will',
#    'discuss',
#    'the',
#    'location',
#    'your',
#    'hidden',
#    'rebel',
#    'base.'],
#   'VADER'),
#  (['enough', 'this!', 'vader,', 'release', 'him!'], 'RED_LEADER'),
#  (['(over', 'speaker)', 'can', 'you', 'see', 'red', 'five?'], 'RED_LEADER'),
#  (['things', 'always', 'change.'], 'BIGGS'),
#  (['wait', 'minute!'], 'LUKE'),
#  (['you', 'know', 'the', 'rebellion', 'against', 'the', 'empire?'], 'LUKE'),
#  (['looks',
#    'like',
#    "i'm",
#    'going',
#    'nowhere.',
#    'have',
#    'finish',
#    'cleaning',
#    'those',
#    'droids.'],
#   'LUKE'),
#  (['call', 'luck.'], 'HAN'),
#  (['your',
#    'uncle',
#    'could',
#    'hold',
#    'off',
#    'whole',
#    'colony',
#    'sandpeople',
#    'with',
#    'one',
#    'blaster.'],
#   'BIGGS'),
#  (["i'm", 'him,', 'luke!'], 'RED_LEADER'),
#  (['(over', 'speaker)', 'this', 'red', 'two.', 'flying', 'toward', 'you.'],
#   'RED_LEADER'),
#  (['let', 'him', 'go!', 'stay', 'the', 'leader!'], 'VADER'),
#  (['on,',
#    'on.',
#    "can't",
#    'understand',
#    'how',
#    'got',
#    'those',
#    'troopers.',
#    'thought',
#    'were',
#    'dead.'],
#   'LUKE'),
#  (["here's", 'where', 'the', 'fun', 'begins!'], 'HAN'),
#  (['oh,',
#    'my.',
#    "i'd",
#    'forgotten',
#    'how',
#    'much',
#    'hate',
#    'space',
#    'travel.'],
#   'THREEPIO'),
#  (['blast', 'it!', 'wedge', 'where', 'are', 'you?'], 'LUKE'),
#  (['could', 'worse...'], 'LEIA'),
#  (['the',
#    "ship's",
#    'all',
#    'yours.',
#    'the',
#    'scanners',
#    'pick',
#    'anything,',
#    'report',
#    'immediately.',
#    'all',
#    'right,',
#    "let's",
#    'go.'],
#   'TROOPER'),
#  (['oh,', 'no!'], 'THREEPIO'),
#  (['(laughing)',
#    'with',
#    'the',
#    'blast',
#    'shield',
#    'down,',
#    "can't",
#    'even',
#    'see.',
#    'how',
#    'supposed',
#    'fight?'],
#   'LUKE'),
#  (['which', 'way?'], 'TROOPER'),
#  (['what?', 'how?'], 'LUKE'),
#  (['(over', 'headset)', 'coming', 'point', 'three', 'five.'], 'LUKE'),
#  (['not',
#    'bad',
#    'bit',
#    'rescuing,',
#    'huh?',
#    'you',
#    'know,',
#    'sometimes',
#    'even',
#    'amaze',
#    'myself.'],
#   'HAN'),
#  (['(over', 'speaker)', 'watch', 'your', 'back,', 'luke!'], 'RED_LEADER'),
#  (['have', 'very', 'bad', 'feeling', 'about', 'this.'], 'LUKE'),
#  (['take',
#    'over!',
#    '(pointing',
#    'the',
#    'dead',
#    'officer)',
#    'see',
#    'him!',
#    'look',
#    'there!'],
#   'TROOPER'),
#  (['blast', 'it,', 'will', 'you!', "gun's", 'jammed.'], 'LUKE'),
#  (['oh,',
#    'my!',
#    'artoo!',
#    'can',
#    'you',
#    'hear',
#    'me?',
#    'say',
#    'something!',
#    '(to',
#    'mechanic)',
#    'you',
#    'can',
#    'repair',
#    'him,',
#    "can't",
#    'you?'],
#   'THREEPIO'),
#  (['open', 'the', 'blast', 'doors!', 'open', 'the', 'blast', 'doors!'],
#   'TROOPER'),
#  (['think',
#    'she',
#    'was',
#    'passenger',
#    'our',
#    'last',
#    'voyage.',
#    'person',
#    'some',
#    'importance,',
#    'sir',
#    'believe.',
#    'our',
#    'captain',
#    'was',
#    'attached',
#    'to...'],
#   'THREEPIO'),
#  (['think',
#    'thought',
#    'was.',
#    'next',
#    'time',
#    "don't",
#    'send',
#    'one',
#    'those',
#    'twerps.',
#    "you've",
#    'got',
#    'something',
#    'say',
#    'me,',
#    'come',
#    'see',
#    'yourself.'],
#   'HAN'),
#  (["they're", 'dantooine.'], 'LEIA'),
#  (['better', 'her', 'than', 'me...'], 'HAN'),
#  (['(over', 'comlink)', 'three-two-six-eight-two-seven.'], 'HAN'),
#  (['why', 'are', 'still', 'moving', 'towards', 'it?'], 'LUKE'),
#  (['(laughing)',
#    'hey,',
#    'knew',
#    'there',
#    'was',
#    'more',
#    'you',
#    'than',
#    'money.'],
#   'LEIA'),
#  (['she',
#    'must',
#    'have',
#    'hidden',
#    'the',
#    'plans',
#    'the',
#    'escape',
#    'pod.',
#    'send',
#    'detachment',
#    'down',
#    'retrieve',
#    'them.',
#    'see',
#    'personally,',
#    'commander.',
#    "there'll",
#    'one',
#    'stop',
#    'this',
#    'time.'],
#   'VADER'),
#  (['luke,',
#    "didn't",
#    'come',
#    'back',
#    'just',
#    'say',
#    'good-bye...',
#    "shouldn't",
#    'tell',
#    'you',
#    'this,',
#    'but',
#    "you're",
#    'the',
#    'only',
#    'one',
#    'can',
#    'trust...',
#    'and',
#    "don't",
#    'come',
#    'back,',
#    'want',
#    'somebody',
#    'know.'],
#   'BIGGS'),
#  (['sign', 'any...', 'wait!'], 'LUKE'),
#  (['(to',
#    'luke)',
#    'come',
#    'on,',
#    'buddy,',
#    "we're",
#    'not',
#    'out',
#    'this',
#    'yet!'],
#   'HAN'),
#  (['the',
#    'regional',
#    'governors',
#    'now',
#    'have',
#    'direct',
#    'control',
#    'over',
#    'territories.',
#    'fear',
#    'will',
#    'keep',
#    'the',
#    'local',
#    'systems',
#    'line.',
#    'fear',
#    'this',
#    'battle',
#    'station.'],
#   'RED_LEADER'),
#  (['think', 'uncle', 'knew', 'him.', 'said', 'was', 'dead.'], 'LUKE'),
#  (['with', 'pleasure.'], 'TROOPER'),
#  (["there's",
#    "nothin'",
#    'can',
#    'about',
#    'it,',
#    'kid.',
#    "i'm",
#    'full',
#    'power.',
#    "i'm",
#    'going',
#    'have',
#    'shut',
#    'down.',
#    'but',
#    "they're",
#    'not',
#    'going',
#    'get',
#    'without',
#    'fight!'],
#   'HAN'),
#  (['how', 'could', 'stupid?', "he's", 'nowhere', 'sight.', 'blast', 'it!'],
#   'LUKE'),
#  (['get',
#    'scanning',
#    'crew',
#    'here',
#    'the',
#    'double.',
#    'want',
#    'every',
#    'part',
#    'this',
#    'ship',
#    'checked!'],
#   'OFFICER'),
#  (['luke,', 'let', 'know', 'when', "you're", 'going', 'in.'], 'RED_LEADER'),
#  (["don't",
#    'too',
#    'proud',
#    'this',
#    'technological',
#    'terror',
#    "you've",
#    'constructed.',
#    'the',
#    'ability',
#    'destroy',
#    'planet',
#    'insignificant',
#    'next',
#    'the',
#    'power',
#    'the',
#    'force.'],
#   'VADER'),
#  (['this',
#    'bickering',
#    'pointless.',
#    'lord',
#    'vader',
#    'will',
#    'provide',
#    'with',
#    'the',
#    'location',
#    'the',
#    'rebel',
#    'fortress',
#    'the',
#    'time',
#    'this',
#    'station',
#    'operational.',
#    'will',
#    'then',
#    'crush',
#    'the',
#    'rebellion',
#    'with',
#    'one',
#    'swift',
#    'stroke.'],
#   'RED_LEADER'),
#  (["we'll", 'stay', 'back', 'far', 'enough', 'cover', 'you.'], 'BIGGS'),
#  (['this',
#    'will',
#    'day',
#    'long',
#    'remembered.',
#    'has',
#    'seen',
#    'the',
#    'end',
#    'kenobi',
#    'and',
#    'will',
#    'soon',
#    'see',
#    'the',
#    'end',
#    'the',
#    'rebellion.'],
#   'VADER'),
#  (['and',
#    "don't",
#    'let',
#    'catch',
#    'you',
#    'following',
#    'begging',
#    'for',
#    'help,',
#    'because',
#    'you',
#    "won't",
#    'get',
#    'it.'],
#   'THREEPIO'),
#  (['pardon', 'me,', 'sir,', 'but', "couldn't", 'after', 'him?'], 'THREEPIO'),
#  (['did', 'you', 'find', 'any', 'droids?'], 'VADER'),
#  (['chewie!'], 'HAN'),
#  (['you', 'stations!', '(to', 'another', 'officer)', 'come', 'with', 'me.'],
#   'OFFICER'),
#  (['almost', 'there!'], 'RED_LEADER'),
#  (['what', 'you', 'mean?', 'where', 'it?'], 'LUKE'),
#  (['well,',
#    'not',
#    'unless',
#    'you',
#    'can',
#    'alter',
#    'time,',
#    'speed',
#    'the',
#    'harvest,',
#    'teleport',
#    'off',
#    'this',
#    'rock!'],
#   'LUKE'),
#  (['where', 'are', 'those', 'transmissions', 'you', 'intercepted?'], 'VADER'),
#  (['what',
#    "good's",
#    'reward',
#    'you',
#    "ain't",
#    'around',
#    'use',
#    'it?',
#    'besides,',
#    'attacking',
#    'that',
#    'battle',
#    'station',
#    "ain't",
#    'idea',
#    'courage.',
#    "it's",
#    'more',
#    'like',
#    'suicide.'],
#   'HAN'),
#  (['and', 'hope', 'they', "don't", 'have', 'blasters.'], 'HAN'),
#  (['found', 'the', 'computer', 'outlet,', 'sir.'], 'THREEPIO'),
#  (['well,',
#    "i'll",
#    'the',
#    'academy',
#    'next',
#    'season...',
#    'after',
#    'that',
#    'who',
#    'knows.',
#    "won't",
#    'drafted',
#    'into',
#    'the',
#    'imperial',
#    'starfleet',
#    "that's",
#    'for',
#    'sure...',
#    'take',
#    'care',
#    'yourself,',
#    "you'll",
#    'always',
#    'the',
#    'best',
#    'friend',
#    "i've",
#    'got.'],
#   'LUKE'),
#  (["i'm", 'ready', 'for', 'anything.'], 'LUKE'),
#  (['(to', 'artoo)', 'no.', 'shut', 'them', 'all', 'down!', 'hurry!'],
#   'THREEPIO'),
#  (['easy...', 'you', 'call', 'that', 'easy?'], 'HAN'),
#  (['come', 'on!'], 'LUKE'),
#  (["i'm", 'trying!'], 'LEIA'),
#  (['you',
#    'must',
#    'repair',
#    'him!',
#    'sir,',
#    'any',
#    'circuits',
#    'gears',
#    'will',
#    'help,',
#    "i'll",
#    'gladly',
#    'donate',
#    'them.'],
#   'THREEPIO'),
#  (['commence', 'primary', 'ignition.'], 'VADER'),
#  (['listen',
#    'them!',
#    "they're",
#    'dying,',
#    'artoo!',
#    'curse',
#    'metal',
#    'body!',
#    "wasn't",
#    'fast',
#    'enough.',
#    "it's",
#    'all',
#    'fault!',
#    'poor',
#    'master!'],
#   'THREEPIO'),
#  (['close',
#    'all',
#    'outboard',
#    'shields!',
#    'close',
#    'all',
#    'outboard',
#    'shields!'],
#   'OFFICER'),
#  (['red', 'group,', 'this', 'red', 'leader.'], 'RED_LEADER'),
#  (["it's", 'worse.'], 'HAN'),
#  (['stay', 'attack', 'formation!'], 'VADER'),
#  (["you're",
#    'far',
#    'too',
#    'trusting.',
#    'dantooine',
#    'too',
#    'remote',
#    'make',
#    'effective',
#    'demonstration.',
#    'but',
#    "don't",
#    'worry.',
#    'will',
#    'deal',
#    'with',
#    'your',
#    'rebel',
#    'friends',
#    'soon',
#    'enough.'],
#   'RED_LEADER'),
#  (['yes.'], 'RED_LEADER'),
#  (['(over',
#    'speaker)',
#    'copy,',
#    'gold',
#    'leader.',
#    'move',
#    'into',
#    'position.'],
#   'RED_LEADER'),
#  (['saw', 'part', 'the', 'message', 'was...'], 'LUKE'),
#  (["that's", 'impossible,', 'even', 'for', 'computer.'], 'RED_LEADER'),
#  (["i'll", 'careful', 'than.'], 'LUKE'),
#  (['well,',
#    "i'm",
#    'not',
#    'going',
#    'that',
#    'way.',
#    "it's",
#    'much',
#    'too',
#    'rocky.',
#    'this',
#    'way',
#    'much',
#    'easier.'],
#   'THREEPIO'),
#  (['(sarcastically)',
#    'oh!',
#    'the',
#    'garbage',
#    'chute',
#    'was',
#    'really',
#    'wonderful',
#    'idea.',
#    'what',
#    'incredible',
#    'smell',
#    "you've",
#    'discovered!',
#    "let's",
#    'get',
#    'out',
#    'here!',
#    'get',
#    'away',
#    'from',
#    'there...'],
#   'HAN'),
#  (['come', 'along,', 'artoo.'], 'THREEPIO'),
#  (['oh!',
#    'all',
#    'this',
#    'excitement',
#    'has',
#    'overrun',
#    'the',
#    'circuits',
#    'counterpart',
#    'here.',
#    'you',
#    "don't",
#    'mind,',
#    "i'd",
#    'like',
#    'take',
#    'him',
#    'down',
#    'maintenance.'],
#   'THREEPIO'),
#  (['that', 'oughta', 'hold', 'for', 'while.'], 'LUKE'),
#  (['wish', 'was', 'going...', 'are', 'you', 'going', 'around', 'long?'],
#   'LUKE'),
#  (['blast', 'the', 'door!', 'kid!'], 'HAN'),
#  (["we're",
#    'little',
#    'rushed,',
#    "you'll",
#    'hurry',
#    'aboard',
#    "we'll",
#    'get',
#    'out',
#    'here.'],
#   'HAN'),
#  (['all', 'right.'], 'LUKE'),
#  (['level',
#    'five.',
#    'detention',
#    'block',
#    'a-twenty-',
#    'three.',
#    "i'm",
#    'afraid',
#    "she's",
#    'scheduled',
#    'terminated.'],
#   'THREEPIO'),
#  (['one',
#    "thing's",
#    'for',
#    'sure.',
#    "we're",
#    'all',
#    'going',
#    'lot',
#    'thinner!',
#    '(to',
#    'leia)',
#    'get',
#    'top',
#    'it!'],
#   'HAN'),
#  (['rich?'], 'HAN'),
#  (["what's", 'important?', "what's", 'carrying?'], 'HAN'),
#  (["we're", 'doomed.'], 'THREEPIO'),
#  (["we're", 'doomed!'], 'THREEPIO'),
#  (['you', 'sent', 'greedo', 'blast', 'me.'], 'HAN'),
#  (['(laughing)', 'knew', "you'd", 'come', 'back!', 'just', 'knew', 'it!'],
#   'LUKE'),
#  (['prisoner', 'transfer', 'from', 'block', 'one-one-', 'three-eight.'],
#   'LUKE'),
#  (["you're", 'right,', 'must', 'not', 'allowed', 'escape.'], 'RED_LEADER'),
#  (['hang', 'on,', 'biggs,', "i'm", 'coming', 'in.'], 'LUKE'),
#  (['what?'], 'LEIA'),
#  (['hey,', 'easy', 'with', 'those...'], 'LUKE'),
#  (['for', 'luck!'], 'LEIA'),
#  (['no!'], 'LUKE'),
#  (['your', 'powers', 'are', 'weak,', 'old', 'man.'], 'VADER'),
#  (['anywhere!', 'oh!!'], 'LUKE'),
#  (['seems',
#    'okay,',
#    'can',
#    'get',
#    'it.',
#    'just',
#    'hope',
#    'the',
#    'old',
#    'man',
#    'got',
#    'the',
#    'tractor',
#    'beam',
#    'out',
#    'commission.'],
#   'HAN'),
#  (['come', 'on!', 'luke,', 'its', 'too', 'late!'], 'LEIA'),
#  (["that's",
#    'okay.',
#    "i'm",
#    'never',
#    'coming',
#    'back',
#    'this',
#    'planet',
#    'again.'],
#   'LUKE'),
#  (['oh,',
#    'this',
#    'little',
#    'droid!',
#    'think',
#    "he's",
#    'searching',
#    'for',
#    'his',
#    'former',
#    'master...',
#    "i've",
#    'never',
#    'seen',
#    'such',
#    'devotion',
#    'droid',
#    'before...',
#    'there',
#    'seems',
#    'stopping',
#    'him.',
#    'claims',
#    'the',
#    'property',
#    'obi-wan',
#    'kenobi.',
#    'relative',
#    'yours?',
#    'you',
#    'know',
#    'who',
#    "he's",
#    'talking',
#    'about?'],
#   'LUKE'),
#  (['the',
#    'entire',
#    'starfleet',
#    "couldn't",
#    'destroy',
#    'the',
#    'whole',
#    'planet.',
#    "it'd",
#    'take',
#    'thousand',
#    'ships',
#    'with',
#    'more',
#    'fire',
#    'power',
#    'than',
#    "i've..."],
#   'HAN'),
#  (['you', 'know', "what's", 'going', 'on?'], 'TROOPER'),
#  (['commander,',
#    'tear',
#    'this',
#    'ship',
#    'apart',
#    'until',
#    "you've",
#    'found',
#    'those',
#    'plans',
#    'and',
#    'bring',
#    'the',
#    'ambassador.',
#    'want',
#    'her',
#    'alive!'],
#   'VADER'),
#  (['you', 'can', 'about', 'your', 'business.'], 'TROOPER'),
#  (["we're", 'caught', 'tractor', 'beam!', "it's", 'pulling', 'in!'], 'HAN'),
#  (['looks',
#    'like',
#    'sandpeople',
#    'did',
#    'this,',
#    'all',
#    'right.',
#    'look,',
#    'here',
#    'are',
#    'gaffi',
#    'sticks,',
#    'bantha',
#    'tracks.',
#    "it's",
#    'just...',
#    'never',
#    'heard',
#    'them',
#    'hitting',
#    'anything',
#    'this',
#    'big',
#    'before.'],
#   'LUKE'),
#  (['give', 'regular', 'reports.'], 'TROOPER'),
#  (['the',
#    'more',
#    'you',
#    'tighten',
#    'your',
#    'grip,',
#    'tarkin,',
#    'the',
#    'more',
#    'star',
#    'systems',
#    'will',
#    'slip',
#    'through',
#    'your',
#    'fingers.'],
#   'LEIA'),
#  (['(to', 'chewie)', 'where', 'are', 'you', 'going?'], 'HAN'),
#  (["i'm", 'range.'], 'RED_LEADER'),
#  (['this', 'it!'], 'RED_LEADER'),
#  (['evacuate?',
#    'out',
#    'moment',
#    'triumph?',
#    'think',
#    'you',
#    'overestimate',
#    'their',
#    'chances!'],
#   'RED_LEADER'),
#  (['artoo,',
#    'see',
#    'what',
#    'you',
#    'can',
#    'with',
#    'it.',
#    'hang',
#    'back',
#    'there.'],
#   'LUKE'),
#  (['join', 'the', 'rebellion?!', 'are', 'you', 'kidding!', 'how?'], 'LUKE'),
#  (['yes.'], 'RED_LEADER'),
#  (['thought',
#    'you',
#    'were',
#    'going',
#    'the',
#    'academy',
#    'next',
#    'term.',
#    "you'll",
#    'get',
#    'your',
#    'chance',
#    'get',
#    'off',
#    'this',
#    'rock.'],
#   'BIGGS'),
#  (['lock', 's-foils', 'attack', 'position.'], 'RED_LEADER'),
#  (["i'm", 'not', 'the', 'type', 'run.'], 'HAN'),
#  (['shut',
#    'down',
#    'all',
#    'the',
#    'garbage',
#    'mashers',
#    'the',
#    'detention',
#    'level.'],
#   'LUKE'),
#  (['least', 'the', 'information', 'artoo', 'still', 'intact.'], 'LEIA'),
#  (['okay.',
#    'you',
#    'guys',
#    'got',
#    'yourself',
#    'ship.',
#    "we'll",
#    'leave',
#    'soon',
#    "you're",
#    'ready.',
#    'docking',
#    'bay',
#    'ninety-four.'],
#   'HAN'),
#  (["he's",
#    'got',
#    'follow',
#    'his',
#    'own',
#    'path.',
#    'one',
#    'can',
#    'choose',
#    'for',
#    'him.'],
#   'LEIA'),
#  (['(over',
#    'comlink)',
#    'will',
#    'you',
#    'shut',
#    'and',
#    'listen',
#    'me?',
#    'shut',
#    'down',
#    'all',
#    'garbage',
#    'mashers',
#    'the',
#    'detention',
#    'level,',
#    'will',
#    'you?',
#    'you',
#    'copy?'],
#   'LUKE'),
#  (['copy,', 'gold', 'five.'], 'RED_LEADER'),
#  (["don't", 'just', 'stand', 'there.', 'try', 'brace', 'with', 'something.'],
#   'LEIA'),
#  (["i've",
#    'got',
#    'get',
#    'aboard.',
#    'listen,',
#    "you'll",
#    'tell',
#    'your',
#    'stories',
#    'when',
#    'come',
#    'back.',
#    'all',
#    'right?'],
#   'BIGGS'),
#  (['(into', 'mike)', "you're", 'all', 'clear,', 'kid.'], 'HAN'),
#  (['what?'], 'VADER'),
#  (['get', 'him!'], 'HAN'),
#  (['ben', 'kenobi', 'here!', 'where', 'he?'], 'LEIA'),
#  (['oh,',
#    'says',
#    "it's",
#    'nothing,',
#    'sir.',
#    'merely',
#    'malfunction.',
#    'old',
#    'data.',
#    'pay',
#    'mind.'],
#   'THREEPIO'),
#  (['hang', 'tight,artoo,', "you've", 'got', 'come', 'back.'], 'THREEPIO'),
#  (["we've", 'lost', 'lateral', 'controls.'], 'LEIA'),
#  (["i'm", 'hit,', 'but', 'not', 'bad.'], 'LUKE'),
#  (['what', 'about', 'the', 'tower?'], 'RED_LEADER'),
#  (["you're", 'who?'], 'LEIA'),
#  (['where', 'did', 'you', 'dig', 'that', 'old', 'fossil?'], 'HAN'),
#  (['over', 'here!', 'help!', 'please,', 'help!'], 'THREEPIO'),
#  (["don't", 'worry,', 'chewie.', 'think', 'know', 'what', 'has', 'mind.'],
#   'HAN'),
#  (['sorry!'], 'RED_LEADER'),
#  (['old',
#    'ben',
#    'kenobi',
#    'lives',
#    'out',
#    'this',
#    'direction',
#    'somewhere,',
#    'but',
#    "don't",
#    'see',
#    'how',
#    'that',
#    'unit',
#    'could',
#    'have',
#    'come',
#    'this',
#    'far.',
#    'must',
#    'have',
#    'missed',
#    'him.',
#    'uncle',
#    'owen',
#    "isn't",
#    'going',
#    'take',
#    'this',
#    'very',
#    'well.'],
#   'LUKE'),
#  (['(over', 'headset)', 'switch', 'your', 'deflectors', 'on.'], 'RED_LEADER'),
#  (["that's",
#    'battle,',
#    'hot',
#    'shot...',
#    "they're",
#    'just',
#    'sitting',
#    'there!',
#    'probably',
#    'freighter-tanker',
#    'refueling.'],
#   'BIGGS'),
#  (['you', 'wish.'], 'VADER'),
#  (['wait', 'minute,', 'where', 'are', 'you', 'going?'], 'THREEPIO'),
#  (['master',
#    'luke,',
#    'sir!',
#    'pardon',
#    'for',
#    'asking...',
#    'but,',
#    'ah...',
#    'what',
#    'should',
#    'artoo',
#    'and',
#    "we're",
#    'discovered',
#    'here?'],
#   'THREEPIO'),
#  (['luke!',
#    "don't",
#    'believe',
#    'it!',
#    "how'd",
#    'you',
#    'get',
#    'here...',
#    'are',
#    'you',
#    'going',
#    'out',
#    'with',
#    'us?!'],
#   'BIGGS'),
#  (['uh...', 'threepio,', 'hand', 'those', 'binders', 'there', 'will', 'you?'],
#   'LUKE'),
#  (["it's", 'away!'], 'RED_LEADER'),
#  (["she'll",
#    'make',
#    'point',
#    'five',
#    'beyond',
#    'the',
#    'speed',
#    'light.',
#    'she',
#    'may',
#    'not',
#    'look',
#    'like',
#    'much,',
#    'but',
#    "she's",
#    'got',
#    'where',
#    'counts,',
#    'kid.',
#    "i've",
#    'added',
#    'some',
#    'special',
#    'modifications',
#    'myself.'],
#   'HAN'),
#  (['oh,', 'think', 'just', 'blasted', 'it.'], 'LUKE'),
#  (['the', 'ship', 'all', 'right?'], 'LUKE'),
#  (['that',
#    "doesn't",
#    'sound',
#    'too',
#    'hard.',
#    'besides,',
#    'they',
#    'let',
#    'go.',
#    "it's",
#    'the',
#    'only',
#    'explanation',
#    'for',
#    'the',
#    'ease',
#    'our',
#    'escape.'],
#   'LEIA'),
#  (['you',
#    'know,',
#    'think',
#    'that',
#    'unit',
#    'bought',
#    'might',
#    'have',
#    'been',
#    'stolen.'],
#   'LUKE'),
#  (['there', 'more', 'this', 'recording?'], 'LUKE'),
#  (["we've",
#    'been',
#    'cut',
#    'off!',
#    'are',
#    'there',
#    'any',
#    'other',
#    'ways',
#    'out',
#    'the',
#    'cell',
#    'bay?...',
#    'what',
#    'was',
#    'that?',
#    "didn't",
#    'copy!'],
#   'LUKE'),
#  (["it's", 'too', 'big', 'space', 'station.'], 'HAN'),
#  (["don't", 'know,', 'just', 'let', 'and', 'disappeared...'], 'LUKE'),
#  (["can't", 'get', 'out', 'that', 'way.'], 'HAN'),
#  (['look',
#    "who's",
#    'talking.',
#    'now',
#    'that',
#    "you've",
#    'been',
#    'around',
#    'those',
#    'giant',
#    'starships',
#    "you're",
#    'beginning',
#    'sound',
#    'like',
#    'uncle.',
#    "you've",
#    'gotten',
#    'soft',
#    'the',
#    'city...'],
#   'LUKE'),
#  (["we're",
#    'position.',
#    "i'm",
#    'going',
#    'cut',
#    'across',
#    'the',
#    'axis',
#    'and',
#    'try',
#    'and',
#    'draw',
#    'their',
#    'fire.'],
#   'RED_LEADER'),
#  (['long,', 'luke.'], 'BIGGS'),
#  (["didn't", 'just', 'leave', 'this', 'party?'], 'HAN'),
#  (['my...',
#    'sir,',
#    'says',
#    'there',
#    'are',
#    'several',
#    'creatures',
#    'approaching',
#    'from',
#    'the',
#    'southeast.'],
#   'THREEPIO'),
#  (["i've", 'missed', 'you', 'kid.'], 'BIGGS'),
#  (['there',
#    'are',
#    'two',
#    'banthas',
#    'down',
#    'there',
#    'but',
#    "don't",
#    'see',
#    'any...',
#    'wait',
#    'second,',
#    "they're",
#    'sandpeople',
#    'all',
#    'right.',
#    'can',
#    'see',
#    'one',
#    'them',
#    'now.'],
#   'LUKE'),
#  (['look,',
#    'going',
#    'good',
#    'against',
#    'remotes',
#    'one',
#    'thing.',
#    'going',
#    'good',
#    'against',
#    'the',
#    'living?',
#    "that's",
#    'something',
#    'else.'],
#   'HAN'),
#  (["there'll", 'escape', 'for', 'the', 'princess', 'this', 'time.'],
#   'THREEPIO'),
#  (['see',
#    'your',
#    'point,',
#    'sir.',
#    'suggest',
#    'new',
#    'strategy,',
#    'artoo.',
#    'let',
#    'the',
#    'wookiee',
#    'win.'],
#   'THREEPIO'),
#  (["that's",
#    'funny,',
#    'the',
#    'damage',
#    "doesn't",
#    'look',
#    'bad',
#    'from',
#    'out',
#    'here.'],
#   'THREEPIO'),
#  (['you', 'fought', 'the', 'clone', 'wars?'], 'LUKE'),
#  (['lock', 'the', 'door,', 'artoo.'], 'THREEPIO'),
#  (['are', 'you', 'all', 'right?'], 'BIGGS'),
#  (['look,',
#    'can',
#    'take',
#    'you',
#    'far',
#    'anchorhead.',
#    'you',
#    'can',
#    'get',
#    'transport',
#    'there',
#    'mos',
#    'eisley',
#    'wherever',
#    "you're",
#    'going.'],
#   'LUKE'),
#  (["don't",
#    'have',
#    'time',
#    'for',
#    'our',
#    'sorrows,',
#    'commander.',
#    'the',
#    'battle',
#    'station',
#    'has',
#    'surely',
#    'tracked',
#    'here.',
#    '(looking',
#    'pointedly',
#    'han)',
#    "it's",
#    'the',
#    'only',
#    'explanation',
#    'for',
#    'the',
#    'ease',
#    'our',
#    'escape.',
#    'you',
#    'must',
#    'use',
#    'the',
#    'information',
#    'this',
#    'unit',
#    'plan',
#    'the',
#    'attack.',
#    'our',
#    'only',
#    'hope.'],
#   'LEIA'),
#  (['still,',
#    "she's",
#    'got',
#    'lot',
#    'spirit.',
#    "don't",
#    'know,',
#    'what',
#    'you',
#    'think?',
#    'you',
#    'think',
#    'princess',
#    'and',
#    'guy',
#    'like',
#    'me...'],
#   'HAN'),
#  (['(to',
#    'artoo)',
#    'thank',
#    'goodness,',
#    'they',
#    "haven't",
#    'found',
#    'them!',
#    'where',
#    'could',
#    'they',
#    'be?'],
#   'THREEPIO'),
#  (['biggs!',
#    'course,',
#    "i'll",
#    'there',
#    'with',
#    'you!',
#    'listen,',
#    'have',
#    'got',
#    'some',
#    'stories',
#    'tell...'],
#   'LUKE'),
#  (['would',
#    'much',
#    'rather',
#    'have',
#    'gone',
#    'with',
#    'master',
#    'luke',
#    'than',
#    'stay',
#    'here',
#    'with',
#    'you.',
#    "don't",
#    'know',
#    'what',
#    'all',
#    'the',
#    'trouble',
#    'about,',
#    'but',
#    "i'm",
#    'sure',
#    'must',
#    'your',
#    'fault.'],
#   'THREEPIO'),
#  (['you',
#    'got',
#    'lot',
#    'carbon',
#    'scoring',
#    'here.',
#    'looks',
#    'like',
#    'you',
#    'boys',
#    'have',
#    'seen',
#    'lot',
#    'action.'],
#   'LUKE'),
#  (['(over',
#    'speaker)',
#    'biggs,',
#    'wedge,',
#    "let's",
#    'close',
#    'up.',
#    "we're",
#    'going',
#    'in.',
#    "we're",
#    'going',
#    'full',
#    'throttle.'],
#   'LUKE'),
#  (['wonder',
#    'who',
#    'she',
#    'is.',
#    'sounds',
#    'like',
#    "she's",
#    'trouble.',
#    "i'd",
#    'better',
#    'play',
#    'back',
#    'the',
#    'whole',
#    'thing.'],
#   'LUKE'),
#  (["can't"], 'LEIA'),
#  (['all',
#    'right.',
#    'well,',
#    'take',
#    'care',
#    'yourself,',
#    'han.',
#    'guess',
#    "that's",
#    'what',
#    "you're",
#    'best',
#    'at,',
#    "isn't",
#    'it?'],
#   'LUKE'),
#  (['yeah,', 'but', 'this', 'time', 'got', 'the', 'money.'], 'HAN'),
#  (['damn', 'fool.', 'knew', 'that', 'you', 'were', 'going', 'say', 'that!'],
#   'HAN'),
#  (['think',
#    'can',
#    'get',
#    'him',
#    'before',
#    'gets',
#    'there...',
#    "he's",
#    'almost',
#    'range.'],
#   'HAN'),
#  (["it'll",
#    'take',
#    'few',
#    'moments',
#    'get',
#    'the',
#    'coordinates',
#    'from',
#    'the',
#    'navi-computer.'],
#   'HAN'),
#  (['bring',
#    'them',
#    'on!',
#    'prefer',
#    'straight',
#    'fight',
#    'all',
#    'this',
#    'sneaking',
#    'around.'],
#   'HAN'),
#  (['look', 'the', 'size', 'that', 'thing!'], 'RED_LEADER'),
#  (['han',
#    'solo.',
#    "i'm",
#    'captain',
#    'the',
#    'millennium',
#    'falcon.',
#    'chewie',
#    'here',
#    'tells',
#    "you're",
#    'looking',
#    'for',
#    'passage',
#    'the',
#    'alderaan',
#    'system.'],
#   'HAN'),
#  (['know,',
#    'but',
#    "he's",
#    'got',
#    'enough',
#    'vaporators',
#    'going',
#    'make',
#    'the',
#    'place',
#    'pay',
#    'off.',
#    'needs',
#    'for',
#    'just',
#    'one',
#    'more',
#    'season.',
#    "can't",
#    'leave',
#    'him',
#    'now.'],
#   'LUKE'),
#  (['the', 'princess!', 'put', 'all', 'sections', 'alert!'], 'RED_LEADER'),
#  (['looks',
#    'like',
#    "somebody's",
#    'beginning',
#    'take',
#    'interest',
#    'your',
#    'handiwork.'],
#   'HAN'),
#  (['(over', 'headset)', 'get', 'set', 'make', 'your', 'attack', 'run.'],
#   'RED_LEADER'),
#  (['what',
#    'message?',
#    'the',
#    'one',
#    "you're",
#    'carrying',
#    'inside',
#    'your',
#    'rusty',
#    'innards!'],
#   'THREEPIO'),
#  (['blast', "'em!"], 'TROOPER'),
#  (['hope',
#    'the',
#    'old',
#    'man',
#    'got',
#    'that',
#    'tractor',
#    'beam',
#    'out',
#    'commission,',
#    'this',
#    'going',
#    'real',
#    'short',
#    'trip.',
#    'okay,',
#    'hit',
#    'it!'],
#   'HAN'),
#  (['then', 'guess', "won't", 'see', 'you.'], 'LUKE'),
#  (['where', 'could', 'they', 'be?'], 'THREEPIO'),
#  (['behave',
#    'yourself,',
#    'artoo.',
#    "you're",
#    'going',
#    'get',
#    'trouble.',
#    "it's",
#    'all',
#    'right,',
#    'you',
#    'can',
#    'trust',
#    'him.',
#    "he's",
#    'our',
#    'new',
#    'master.'],
#   'THREEPIO'),
#  (['let', 'see', 'your', 'identification.'], 'TROOPER'),
#  (['jabba,', "i'll", 'pay', 'you', 'because', "it's", 'pleasure.'], 'HAN'),
#  (["you're",
#    'crazy!',
#    'you',
#    'could',
#    'wander',
#    'around',
#    'forever',
#    'trying',
#    'find',
#    'them.'],
#   'LUKE'),
#  (["target's", 'coming', 'up!'], 'RED_LEADER'),
#  (['yeah,', 'take', 'away.'], 'LUKE'),
#  (["don't",
#    'call',
#    'mindless',
#    'philosopher,',
#    'you',
#    'overweight',
#    'glob',
#    'grease!',
#    'now',
#    'come',
#    'out',
#    'before',
#    'somebody',
#    'sees',
#    'you.'],
#   'THREEPIO'),
#  (['just', 'hold', 'them', 'off', 'for', 'few', 'seconds.'], 'RED_LEADER'),
#  (['all',
#    'right,',
#    'check',
#    'that',
#    'side',
#    'the',
#    'street.',
#    "it's",
#    'secure.',
#    'move',
#    'the',
#    'next',
#    'door.'],
#   'TROOPER'),
#  (["don't", 'need', 'see', 'his', 'identification.'], 'TROOPER'),
#  (['not',
#    'after',
#    'demonstrate',
#    'the',
#    'power',
#    'this',
#    'station.',
#    'way,',
#    'you',
#    'have',
#    'determined',
#    'the',
#    'choice',
#    'the',
#    'planet',
#    "that'll",
#    'destroyed',
#    'first.',
#    'since',
#    'you',
#    'are',
#    'reluctant',
#    'provide',
#    'with',
#    'the',
#    'location',
#    'the',
#    'rebel',
#    'base,',
#    'have',
#    'chosen',
#    'test',
#    'this',
#    "station's",
#    'destructive',
#    'power...',
#    'your',
#    'home',
#    'planet',
#    'alderaan.'],
#   'RED_LEADER'),
#  (['several,',
#    'think.',
#    'actually,',
#    "there's",
#    'not',
#    'much',
#    'tell.',
#    "i'm",
#    'not',
#    'much',
#    'more',
#    'than',
#    'interpreter,',
#    'and',
#    'not',
#    'very',
#    'good',
#    'telling',
#    'stories.',
#    'well,',
#    'not',
#    'making',
#    'them',
#    'interesting,',
#    'anyways.'],
#   'THREEPIO'),
#  (['should',
#    'have',
#    'known',
#    'better',
#    'than',
#    'trust',
#    'the',
#    'logic',
#    'half-sized',
#    'thermocapsulary',
#    'dehousing',
#    'assister...'],
#   'THREEPIO'),
#  (["i'm", 'sorry.'], 'LUKE'),
#  (['and', "i'm", 'stuck', 'here...'], 'LUKE'),
#  (['(laughing)', 'hey!', 'hey!'], 'HAN'),
#  (["now's", 'our', 'chance!', 'go!'], 'HAN'),
#  (['yes.'], 'RED_LEADER'),
#  (['(getting',
#    'angry)',
#    'come',
#    'on!',
#    'why',
#    "don't",
#    'you',
#    'take',
#    'look',
#    'around?',
#    'you',
#    'know',
#    "what's",
#    'about',
#    'happen,',
#    'what',
#    "they're",
#    'against.',
#    'they',
#    'could',
#    'use',
#    'good',
#    'pilot',
#    'like',
#    'you.',
#    "you're",
#    'turning',
#    'your',
#    'back',
#    'them.'],
#   'LUKE'),
#  (['(over', 'headset)', 'double', 'front!'], 'RED_LEADER'),
#  (['did', 'it!'], 'LEIA'),
#  (['grow',
#    'tired',
#    'asking',
#    'this.',
#    "it'll",
#    'the',
#    'last',
#    'time.',
#    'where',
#    'the',
#    'rebel',
#    'base?'],
#   'RED_LEADER'),
#  (['great', 'shot,', 'kid.', 'that', 'was', 'one', 'million.'], 'HAN'),
#  (['look!'], 'LUKE'),
#  (['she', 'lied!', 'she', 'lied', 'us!'], 'RED_LEADER'),
#  (['...oh-five;', "we'll", 'cover', 'for', 'you.'], 'LUKE'),
#  (['but', 'sir,', 'nobody', 'worries', 'about', 'upsetting', 'droid.'],
#   'THREEPIO'),
#  (['yes,',
#    'sir.',
#    'think',
#    'those',
#    'new',
#    'droids',
#    'are',
#    'going',
#    'work',
#    'out',
#    'fine.',
#    'fact,',
#    'uh,',
#    'was',
#    'also',
#    'thinking',
#    'about',
#    'our',
#    'agreement',
#    'about',
#    'staying',
#    'another',
#    'season.',
#    'and',
#    'these',
#    'new',
#    'droids',
#    'work',
#    'out,',
#    'want',
#    'transmit',
#    'application',
#    'the',
#    'academy',
#    'this',
#    'year.'],
#   'LUKE'),
#  (['thought',
#    'might',
#    'have',
#    'meant',
#    'old',
#    'ben.',
#    'you',
#    'know',
#    'what',
#    "he's",
#    'talking',
#    'about?',
#    'well,',
#    'wonder',
#    "he's",
#    'related',
#    'ben.'],
#   'LUKE'),
#  (["i've",
#    'been',
#    'waiting',
#    'for',
#    'you,',
#    'obi-wan.',
#    'meet',
#    'again,',
#    'last.',
#    'the',
#    'circle',
#    'now',
#    'complete.'],
#   'VADER'),
#  (["can't", 'shake', 'him!'], 'LUKE'),
#  (['see-threepio!', 'see-threepio!'], 'LUKE'),
#  (['threepio!', 'come', 'threepio!', 'threepio!', 'where', 'could', 'be?'],
#   'LUKE'),
#  (['they',
#    'traced',
#    'the',
#    'robots',
#    'here,',
#    'they',
#    'may',
#    'have',
#    'learned',
#    'who',
#    'they',
#    'sold',
#    'them',
#    'to.',
#    'and',
#    'that',
#    'would',
#    'lead',
#    'them',
#    'home!'],
#   'LUKE'),
#  (['your',
#    'friend',
#    'quite',
#    'mercenary.',
#    'wonder',
#    'really',
#    'cares',
#    'about',
#    'anything...',
#    'anyone.'],
#   'LEIA'),
#  (['what', 'the', 'hell', 'are', 'you', 'doing?'], 'HAN'),
#  (['(very',
#    'animated)',
#    '...so',
#    'cut',
#    'off',
#    'power,',
#    'shut',
#    'down',
#    'the',
#    'afterburners',
#    'and',
#    'came',
#    'low',
#    "deak's",
#    'trail.',
#    'was',
#    'close',
#    'thought',
#    'was',
#    'going',
#    'fry',
#    'instruments.',
#    'was',
#    'busted',
#    'the',
#    'skyhopper',
#    'pretty',
#    'bad.',
#    'uncle',
#    'owen',
#    'was',
#    'pretty',
#    'upset.',
#    'grounded',
#    'for',
#    'the',
#    'rest',
#    'the',
#    'season.',
#    'you',
#    'should',
#    'have',
#    'been',
#    'there...',
#    'was',
#    'fantastic.'],
#   'LUKE'),
#  (['you',
#    'know,',
#    'did',
#    'feel',
#    'something.',
#    'could',
#    'almost',
#    'see',
#    'the',
#    'remote.'],
#   'LUKE'),
#  (['not', 'this', 'ship,', 'sister.'], 'HAN'),
#  (['you',
#    'bet',
#    'could.',
#    "i'm",
#    'not',
#    'such',
#    'bad',
#    'pilot',
#    'myself!',
#    "don't",
#    'have',
#    'sit',
#    'here',
#    'and',
#    'listen...'],
#   'LUKE'),
#  (['right', 'with', 'you,', 'boss.'], 'RED_LEADER'),
#  (["that's",
#    "'cause",
#    'droids',
#    "don't",
#    'pull',
#    "people's",
#    'arms',
#    'out',
#    'their',
#    'socket',
#    'when',
#    'they',
#    'lose.',
#    'wookiees',
#    'are',
#    'known',
#    'that.'],
#   'HAN'),
#  (['got', 'him!'], 'LUKE'),
#  (['you',
#    'ought',
#    'take',
#    'easy',
#    'luke.',
#    'you',
#    'may',
#    'the',
#    'hottest',
#    'bushpilot',
#    'this',
#    'side',
#    'mos',
#    'eisley,',
#    'but',
#    'those',
#    'little',
#    'skyhoppers',
#    'are',
#    'dangerous.',
#    'keep',
#    'up,',
#    'and',
#    'one',
#    'day,',
#    'whammo,',
#    "you're",
#    'going',
#    'nothing',
#    'more',
#    'than',
#    'dark',
#    'spot',
#    'the',
#    'down',
#    'side',
#    'canyon',
#    'wall.'],
#   'BIGGS'),
#  (['get', 'behind', 'me!', 'get', 'behind', 'me!'], 'HAN'),
#  (["i've",
#    'got',
#    'rest',
#    'before',
#    'fall',
#    'apart.',
#    'joints',
#    'are',
#    'almost',
#    'frozen.'],
#   'THREEPIO'),
#  (["can't", 'hold', 'them', 'off', 'forever!', 'now', 'what?'], 'HAN'),
#  (["i've", 'lost', 'artoo!'], 'LUKE'),
#  (["scope's", 'negative.', "don't", 'see', 'anything.'], 'LUKE'),
#  (['no,', 'wait.', "they'll", 'hear!'], 'LEIA'),
#  (['traveling',
#    'through',
#    'hyperspace',
#    "isn't",
#    'like',
#    'dusting',
#    'crops,',
#    'boy!',
#    'without',
#    'precise',
#    'calculations',
#    'could',
#    'fly',
#    'right',
#    'through',
#    'star',
#    'bounce',
#    'too',
#    'close',
#    'supernova',
#    'and',
#    "that'd",
#    'end',
#    'your',
#    'trip',
#    'real',
#    'quick,',
#    "wouldn't",
#    'it?'],
#   'HAN'),
#  (['what', 'kept', 'you?'], 'HAN'),
#  (['even', 'get', 'boarded', 'sometimes.', 'you', 'think', 'had', 'choice?'],
#   'HAN'),
#  (['what?'], 'HAN'),
#  (['who', 'she?', "she's", 'beautiful.'], 'LUKE'),
#  (['have', 'you', 'been', 'many', 'battles?'], 'LUKE'),
#  (['you', 'mean', 'controls', 'your', 'actions?'], 'LUKE'),
#  (['where',
#    'could',
#    'be?',
#    'threepio!',
#    'threepio,',
#    'will',
#    'you',
#    'come',
#    'in?'],
#   'LUKE'),
#  (['help',
#    'me,',
#    'obi-wan',
#    'kenobi.',
#    "you're",
#    'only',
#    'hope.',
#    'help',
#    'me,',
#    'obi-wan',
#    'kenobi.',
#    "you're",
#    'only',
#    'hope.'],
#   'LEIA'),
#  (['so...', 'what', 'you', 'think', 'her,', 'han?'], 'LUKE'),
#  (["don't", 'underestimate', 'the', 'power', 'the', 'force.'], 'VADER'),
#  (['where', 'are', 'you', 'going?', 'come', 'back!'], 'LUKE'),
#  (["didn't",
#    'know',
#    'you',
#    'were',
#    'back!',
#    'when',
#    'did',
#    'you',
#    'get',
#    'in?'],
#   'LUKE'),
#  (['maybe', 'someday...', "i'll", 'keep', 'lookout.'], 'BIGGS'),
#  (['you',
#    'really',
#    'think',
#    "we're",
#    'going',
#    'find',
#    'pilot',
#    'here',
#    "that'll",
#    'take',
#    'alderaan?'],
#   'LUKE'),
#  (['you',
#    'worry',
#    'about',
#    'those',
#    'fighters!',
#    "i'll",
#    'worry',
#    'about',
#    'the',
#    'tower!'],
#   'LUKE'),
#  (['close', 'formation.'], 'VADER'),
# ...
#   'LUKE'),
#  (['this', 'unit', 'has', 'bad', 'motivator.', 'look!'], 'LUKE'),
#  (['wonderful',
#    'girl!',
#    'either',
#    "i'm",
#    'going',
#    'kill',
#    'her',
#    "i'm",
#    'beginning',
#    'like',
#    'her.',
#    'get',
#    'there!'],
#   'HAN'),
#  (["can't", 'abide', 'these', 'jawas.', 'disgusting', 'creatures.'],
#   'THREEPIO'),
#  (['no,', "you're", 'not.', 'what', 'kind', 'talk', 'that?'], 'LUKE'),
#  (['watch', 'yourself!', 'increase', 'speed', 'full', 'throttle!'], 'LUKE'),
#  (['see-threepio,', 'you', 'copy?'], 'LUKE'),
#  (['sense', 'something...', 'presence', "haven't", 'felt', 'since...'],
#   'VADER'),
#  (['ten',
#    'thousand?',
#    'could',
#    'almost',
#    'buy',
#    'our',
#    'own',
#    'ship',
#    'for',
#    'that!'],
#   'LUKE'),
#  (['listen.',
#    "don't",
#    'know',
#    'who',
#    'you',
#    'are,',
#    'where',
#    'you',
#    'came',
#    'from,',
#    'but',
#    'from',
#    'now',
#    'on,',
#    'you',
#    'tell',
#    'you.',
#    'okay?'],
#   'LEIA'),
#  (['hey,',
#    "you're",
#    'not',
#    'permitted',
#    'there.',
#    "it's",
#    'restricted.',
#    "you'll",
#    'deactivated',
#    'for',
#    'sure..'],
#   'THREEPIO'),
#  (['negative!', "didn't", 'in.', 'just', 'impacted', 'the', 'surface.'],
#   'RED_LEADER'),
#  (["i've", 'been', 'waiting', 'for', 'you,', 'jabba.'], 'HAN'),
#  (['looks',
#    'like',
#    'imperial',
#    'cruiser.',
#    'our',
#    'passengers',
#    'must',
#    'hotter',
#    'than',
#    'thought.',
#    'try',
#    'and',
#    'hold',
#    'them',
#    'off.',
#    'angle',
#    'the',
#    'deflector',
#    'shield',
#    'while',
#    'make',
#    'the',
#    'calculations',
#    'for',
#    'the',
#    'jump',
#    'light',
#    'speed.'],
#   'HAN'),
#  (['uh,', 'you', 'can', 'call', 'luke.'], 'LUKE'),
#  (['luke,', 'that', 'speed', 'will', 'you', 'able', 'pull', 'out', 'time?'],
#   'BIGGS'),
#  (["can't", 'see', 'it!', 'where', 'he?!'], 'BIGGS'),
#  (["he'll", 'all', 'right.'], 'LUKE'),
#  (['made', 'fair', 'move.', 'screaming', 'about', "won't", 'help', 'you.'],
#   'THREEPIO'),
#  (['our', 'position', 'correct,', 'except...', 'no,', 'alderaan!'], 'HAN'),
#  (['(to', 'chewie)', 'come', 'here,', 'you', 'big', 'coward!'], 'HAN'),
#  (['this', 'consular', 'ship...', 'were', 'the', 'ambassador?'], 'VADER'),
#  (['(to',
#    'chewie)',
#    "we're",
#    'coming',
#    'the',
#    'sentry',
#    'ships.',
#    'hold',
#    "'em",
#    'off!',
#    'angle',
#    'the',
#    'deflector',
#    'shields',
#    'while',
#    'charge',
#    'the',
#    'main',
#    'guns!'],
#   'HAN'),
#  (["it's",
#    'the',
#    'ship',
#    'that',
#    'made',
#    'the',
#    'kessel',
#    'run',
#    'less',
#    'than',
#    'twelve',
#    'parsecs!'],
#   'HAN'),
#  (['yes,',
#    'greedo.',
#    'matter',
#    'fact,',
#    'was',
#    'just',
#    'going',
#    'see',
#    'your',
#    'boss.',
#    'tell',
#    'jabba',
#    'that',
#    "i've",
#    'got',
#    'his',
#    'money.'],
#   'HAN'),
#  (['what',
#    'mission?',
#    'what',
#    'are',
#    'you',
#    'talking',
#    'about?',
#    "i've",
#    'had',
#    'just',
#    'about',
#    'enough',
#    'you!',
#    'that',
#    'way!',
#    "you'll",
#    'malfunctioning',
#    'within',
#    'day,',
#    'you',
#    'nearsighted',
#    'scrap',
#    'pile!'],
#   'THREEPIO'),
#  (["don't",
#    'know',
#    'what',
#    "you're",
#    'talking',
#    'about.',
#    "i'm",
#    'member',
#    'the',
#    'imperial',
#    'senate',
#    'diplomatic',
#    'mission',
#    'alderaan...'],
#   'LEIA'),
#  (["there's", 'another', 'ship', 'coming', 'in.'], 'HAN'),
#  (['you', 'may', 'fire', 'when', 'ready.'], 'RED_LEADER'),
#  (['only', 'wish', 'ben', 'were', 'here.'], 'LUKE'),
#  (['hokey',
#    'religions',
#    'and',
#    'ancient',
#    'weapons',
#    'are',
#    'match',
#    'for',
#    'good',
#    'blaster',
#    'your',
#    'side,',
#    'kid.'],
#   'HAN'),
#  (["what's", 'that?'], 'THREEPIO'),
#  (["you're",
#    'part',
#    'the',
#    'rebel',
#    'alliance...',
#    'and',
#    'traitor.',
#    'take',
#    'her',
#    'away!'],
#   'VADER'),
#  (["i'm", 'it.'], 'LUKE'),
#  (['anyway,', 'should', 'alderaan', 'about', 'oh-two-hundred', 'hours.'],
#   'HAN'),
#  (["they're",
#    'heading',
#    'this',
#    'direction.',
#    'what',
#    'are',
#    'going',
#    'do?',
#    "we'll",
#    'sent',
#    'the',
#    'spice',
#    'mine',
#    'kessel',
#    'smashed',
#    'into',
#    'who',
#    'knows',
#    'what!'],
#   'THREEPIO'),
#  (["we've",
#    'analyzed',
#    'their',
#    'attack,',
#    'sir,',
#    'and',
#    'there',
#    'danger.',
#    'should',
#    'have',
#    'your',
#    'ship',
#    'standing',
#    'by?'],
#   'OFFICER'),
#  (['watch',
#    'your',
#    'mouth,',
#    'kid,',
#    "you're",
#    'going',
#    'find',
#    'yourself',
#    'floating',
#    'home.',
#    "we'll",
#    'safe',
#    'enough',
#    'once',
#    'make',
#    'the',
#    'jump',
#    'hyperspace.',
#    'besides,',
#    'know',
#    'few',
#    'maneuvers.',
#    "we'll",
#    'lose',
#    'them!'],
#   'HAN'),
#  (['these',
#    'are',
#    'the',
#    'same',
#    'jawas',
#    'that',
#    'sold',
#    'artoo',
#    'and',
#    'threepio.'],
#   'LUKE'),
#  (["i'm", 'way', 'now...'], 'LUKE'),
#  (['what', 'it?'], 'LUKE'),
#  (['(looking', 'his', 'ship)', 'there', 'she', 'is.'], 'HAN'),
#  (['got', 'little', 'cooked,', 'but', "i'm", 'okay.'], 'LUKE'),
#  (['there', 'they', 'are!'], 'LUKE'),
#  (['(over', 'headset)', 'hurry', 'up,', 'luke!'], 'BIGGS'),
#  (['what', 'are', 'you', 'talking', 'about?'], 'LUKE'),
#  (['how', 'long', 'have', 'you', 'had', 'these', 'droids?'], 'TROOPER'),
#  (['help!'], 'LUKE'),
#  (['what', 'it?', 'some', 'kind', 'local', 'trouble?'], 'HAN'),
#  (['what', 'happened?'], 'LEIA'),
#  (["she's", 'rich.'], 'LUKE'),
#  (['that',
#    'unit',
#    'has',
#    'always',
#    'been',
#    'problem.',
#    'these',
#    'astro-droids',
#    'are',
#    'getting',
#    'quite',
#    'out',
#    'hand.',
#    'even',
#    "can't",
#    'understand',
#    'their',
#    'logic',
#    'times.'],
#   'THREEPIO'),
#  (['(over', 'speaker)', "i'm", 'hit!', "can't", 'stay', 'with', 'you.'],
#   'RED_LEADER'),
#  (["it's",
#    'wonder',
#    "you're",
#    'still',
#    'alive.',
#    '(looking',
#    'chewie)',
#    'will',
#    'somebody',
#    'get',
#    'this',
#    'big',
#    'walking',
#    'carpet',
#    'out',
#    'way?'],
#   'LEIA'),
#  (["what's", 'wrong', 'with', 'him', 'now?'], 'LUKE'),
#  (['hey,', 'whoa,', 'just', 'where', 'you', 'think', "you're", 'going?'],
#   'LUKE'),
#  (["can't",
#    'get',
#    'involved!',
#    "i've",
#    'got',
#    'work',
#    'do!',
#    "it's",
#    'not',
#    'that',
#    'like',
#    'the',
#    'empire.',
#    'hate',
#    'it!',
#    'but',
#    "there's",
#    'nothing',
#    'can',
#    'about',
#    'right',
#    'now.',
#    "it's",
#    'such',
#    'long',
#    'way',
#    'from',
#    'here.'],
#   'LUKE'),
#  (['ran', 'into', 'some', 'old', 'friends.'], 'LEIA'),
#  (['no!', 'wait!'], 'LUKE'),
#  (['well,',
#    'wait',
#    'minute.',
#    "where'd",
#    'she',
#    'go?',
#    'bring',
#    'her',
#    'back!',
#    'play',
#    'back',
#    'the',
#    'entire',
#    'message.'],
#   'LUKE'),
#  (['there', "isn't", 'any', 'other', 'way', 'out.'], 'LUKE'),
#  (['(over', 'speaker)', 'negative.'], 'RED_LEADER'),
#  (['did', 'say', 'before!'], 'HAN'),
#  (["don't", 'everyone', 'thank', 'once.'], 'HAN'),
#  (['uncle', 'owen!', 'aunt', 'beru!', 'uncle', 'owen!'], 'LUKE'),
#  (['must', 'have', 'gotten', 'lost,', 'been', 'part', 'convoy', 'something.'],
#   'LUKE'),
#  (["can't", 'believe', "he's", 'gone.'], 'LUKE'),
#  (['says',
#    "he's",
#    'the',
#    'property',
#    'obi-wan',
#    'kenobi,',
#    'resident',
#    'these',
#    'parts.',
#    'and',
#    "it's",
#    'private',
#    'message',
#    'for',
#    'him.',
#    'quite',
#    'frankly,',
#    'sir',
#    "don't",
#    'know',
#    'what',
#    "he's",
#    'talking',
#    'about.',
#    'our',
#    'last',
#    'master',
#    'was',
#    'captain',
#    'antilles,',
#    'but',
#    'with',
#    'what',
#    "we've",
#    'been',
#    'through,',
#    'this',
#    'little',
#    'unit',
#    'has',
#    'become',
#    'bit',
#    'eccentric.'],
#   'THREEPIO'),
#  (['oh,', 'no!'], 'LUKE'),
#  (['governor',
#    'tarkin,',
#    'should',
#    'have',
#    'expected',
#    'find',
#    'you',
#    'holding',
#    "vader's",
#    'leash.',
#    'recognized',
#    'your',
#    'foul',
#    'stench',
#    'when',
#    'was',
#    'brought',
#    'board.'],
#   'LEIA'),
#  (['for',
#    'me,',
#    'sister!',
#    'look,',
#    "ain't",
#    'this',
#    'for',
#    'your',
#    'revolution,',
#    'and',
#    "i'm",
#    'not',
#    'for',
#    'you,',
#    'princess.',
#    'expect',
#    'well',
#    'paid.',
#    "i'm",
#    'for',
#    'the',
#    'money!'],
#   'HAN'),
#  (['(over', 'headset)', 'cut', 'the', 'chatter,', 'red', 'two.'],
#   'RED_LEADER'),
#  (['artoo,', 'try', 'and', 'increase', 'the', 'power!'], 'LUKE'),
#  (["what's", 'your', 'plan?'], 'HAN'),
#  (['oh,', 'no!'], 'LUKE'),
#  (['looks',
#    'like',
#    'you',
#    'managed',
#    'cut',
#    'off',
#    'our',
#    'only',
#    'escape',
#    'route.'],
#   'LEIA'),
#  (['(over',
#    'headset)',
#    'scope',
#    'shows',
#    'the',
#    'tower,',
#    'but',
#    "can't",
#    'see',
#    'the',
#    'exhaust',
#    'port!',
#    'are',
#    'you',
#    'sure',
#    'the',
#    'computer',
#    'can',
#    'hit',
#    'it?'],
#   'RED_LEADER'),
#  (["don't",
#    'think',
#    'can',
#    'make',
#    'it.',
#    'you',
#    'on,',
#    'master',
#    'luke.',
#    "there's",
#    'sense',
#    'you',
#    'risking',
#    'yourself',
#    'account.',
#    "i'm",
#    'done',
#    'for.'],
#   'THREEPIO'),
#  (['whatever',
#    'you',
#    'say.',
#    "i've",
#    'done',
#    'more',
#    'that',
#    'bargained',
#    'for',
#    'this',
#    'trip',
#    'already.'],
#   'HAN'),
#  (['vaporators!',
#    'sir',
#    'first',
#    'job',
#    'was',
#    'programming',
#    'binary',
#    'load',
#    'lifter...',
#    'very',
#    'similar',
#    'your',
#    'vaporators.',
#    'you',
#    'could',
#    'say...'],
#   'THREEPIO'),
#  (['looks',
#    'like',
#    "don't",
#    'have',
#    'much',
#    'choice',
#    'but',
#    "i'll",
#    'remind',
#    'him.'],
#   'LUKE'),
#  (['deactivate!',
#    'well,',
#    'the',
#    'other',
#    'hand',
#    'you',
#    "hadn't",
#    'removed',
#    'his',
#    'restraining',
#    'bolt...'],
#   'THREEPIO'),
#  (['just',
#    "isn't",
#    'fair.',
#    'oh,',
#    'biggs',
#    'right.',
#    "i'm",
#    'never',
#    'gonna',
#    'get',
#    'out',
#    'here!'],
#   'LUKE'),
#  (['great', 'kid!', "don't", 'get', 'cocky.'], 'HAN'),
#  (["it's",
#    'not',
#    'impossible.',
#    'used',
#    "bull's-",
#    'eye',
#    'womp',
#    'rats',
#    't-sixteen',
#    'back',
#    'home.',
#    "they're",
#    'not',
#    'much',
#    'bigger',
#    'than',
#    'two',
#    'meters.'],
#   'LUKE'),
#  (['artoo!', 'artoo-detoo,', 'where', 'are', 'you?'], 'THREEPIO'),
#  (['get', 'the', 'top!'], 'HAN'),
#  (['stop', 'that', 'ship!'], 'TROOPER'),
#  (['this', 'red', 'five;', "i'm", 'going', 'in!'], 'LUKE'),
#  (['oh,', 'excels', 'that,', 'sir.'], 'THREEPIO'),
#  (['what', 'are', 'you', 'talking', 'about?'], 'HAN'),
#  (['so...',
#    'you',
#    'got',
#    'your',
#    'reward',
#    'and',
#    "you're",
#    'just',
#    'leaving',
#    'then?'],
#   'LUKE'),
#  (['well,',
#    "wasn't",
#    'gonna',
#    'let',
#    'you',
#    'get',
#    'all',
#    'the',
#    'credit',
#    'and',
#    'take',
#    'all',
#    'the',
#    'reward.'],
#   'HAN'),
#  (['(to',
#    'artoo)',
#    'just',
#    'you',
#    'reconsider',
#    'playing',
#    'that',
#    'message',
#    'for',
#    'him.'],
#   'THREEPIO'),
#  (['made',
#    'some',
#    'friends',
#    'the',
#    'academy.',
#    '(he',
#    'whispers)',
#    '...when',
#    'our',
#    'frigate',
#    'goes',
#    'one',
#    'the',
#    'central',
#    'systems,',
#    "we're",
#    'going',
#    'jump',
#    'ship',
#    'and',
#    'join',
#    'the',
#    'alliance...'],
#   'BIGGS'),
#  (['yes.',
#    'rich,',
#    'powerful!',
#    'listen,',
#    'you',
#    'were',
#    'rescue',
#    'her,',
#    'the',
#    'reward',
#    'would',
#    'be...'],
#   'LUKE'),
#  (['you', 'know', 'him!'], 'LUKE'),
#  (['(over',
#    'comlink)',
#    'shut',
#    'down',
#    'all',
#    'the',
#    'garbage',
#    'mashers',
#    'the',
#    'detention',
#    'level.'],
#   'LUKE'),
#  (['you', 'came', 'that', 'thing?', "you're", 'braver', 'that', 'thought.'],
#   'LEIA'),
#  (['no,', "don't", 'like', 'you', 'either.'], 'THREEPIO'),
#  (['well,',
#    'things',
#    "haven't",
#    'been',
#    'the',
#    'same',
#    'since',
#    'you',
#    'left,',
#    'biggs.',
#    "it's",
#    'been',
#    'so...',
#    'quiet.'],
#   'LUKE'),
#  (['quick,',
#    "we've",
#    'got',
#    'get',
#    'across.',
#    'find',
#    'the',
#    'control',
#    'that',
#    'extends',
#    'the',
#    'bridge.'],
#   'LEIA'),
#  (['see,', 'sir', 'luke.'], 'THREEPIO'),
#  (['no,',
#    'father',
#    "didn't",
#    'fight',
#    'the',
#    'wars.',
#    'was',
#    'navigator',
#    'spice',
#    'freighter.'],
#   'LUKE'),
#  (['secret',
#    'mission?',
#    'what',
#    'plans?',
#    'what',
#    'are',
#    'you',
#    'talking',
#    'about?',
#    "i'm",
#    'not',
#    'getting',
#    'there!'],
#   'THREEPIO'),
#  (['(gasping)', 'think', 'took', 'wrong', 'turn.'], 'LUKE'),
#  (['you',
#    'know,',
#    'between',
#    'his',
#    'howling',
#    'and',
#    'your',
#    'blasting',
#    'everything',
#    'sight,',
#    "it's",
#    'wonder',
#    'the',
#    'whole',
#    'station',
#    "doesn't",
#    'know',
#    "we're",
#    'here.'],
#   'LUKE'),
#  (['thanks,', 'wedge.'], 'LUKE'),
#  (["don't", 'know,', 'can', 'imagine', 'quite', 'bit!'], 'HAN'),
#  (['(into', 'intercom)', 'here', 'they', 'come!'], 'LEIA'),
#  (['all',
#    'right,',
#    "i'll",
#    'there',
#    'few',
#    'minutes.',
#    'boy,',
#    'gonna',
#    'get',
#    'it.'],
#   'LUKE'),
#  (['expected', 'you', 'would', 'be.'], 'JABBA'),
#  (['(over', 'speaker)', 'see', 'it.', 'stay', 'low.'], 'RED_LEADER'),
#  (['are', 'you', 'sure', 'this', 'things', 'safe?'], 'THREEPIO'),
#  (['the', 'force', 'strong', 'with', 'this', 'one!'], 'VADER'),
#  (['where', 'must', 'have', 'taken', 'bad', 'step...'], 'THREEPIO'),
#  (['where', 'are', 'you', 'taking', 'this...', 'thing?'], 'OFFICER'),
#  (["she'll", 'all', 'right.', 'inform', 'lord', 'vader', 'have', 'prisoner.'],
#   'TROOPER'),
#  (['says',
#    'the',
#    'restraining',
#    'bolt',
#    'has',
#    'short',
#    'circuited',
#    'his',
#    'recording',
#    'system.',
#    'suggests',
#    'that',
#    'you',
#    'remove',
#    'the',
#    'bolt,',
#    'might',
#    'able',
#    'play',
#    'back',
#    'the',
#    'entire',
#    'recording.'],
#   'THREEPIO'),
#  (['all',
#    'right,',
#    'come',
#    'on!',
#    'and',
#    'the',
#    'red',
#    'one,',
#    'come',
#    'on.',
#    'well,',
#    'come',
#    'on,',
#    'red,',
#    "let's",
#    'go.'],
#   'LUKE'),
#  (['(voice)',
#    'for',
#    'the',
#    'moment.',
#    'uh,',
#    "we're",
#    'the',
#    'main',
#    'hangar',
#    'across',
#    'from',
#    'the',
#    'ship.'],
#   'THREEPIO'),
#  (['well,',
#    "ain't",
#    'going',
#    'around',
#    'long',
#    'enough',
#    'tell',
#    'anyone',
#    'about',
#    'us.'],
#   'HAN'),
#  (['what', 'desolate', 'place', 'this', 'is.'], 'THREEPIO'),
#  (['why',
#    "don't",
#    'you',
#    'outrun',
#    'them?',
#    'thought',
#    'you',
#    'said',
#    'this',
#    'thing',
#    'was',
#    'fast.'],
#   'LUKE'),
#  (['(over', 'speaker)', 'get', 'clear,', 'wedge.'], 'LUKE'),
#  (['sir,',
#    'luke',
#    'the',
#    'best',
#    'bushpilot',
#    'the',
#    'outer',
#    'rim',
#    'territories.'],
#   'BIGGS'),
#  (['looks', 'like', "we're", 'coming', 'alderaan.'], 'HAN'),
#  (['red', 'two', 'standing', 'by.'], 'RED_LEADER'),
#  (['think',
#    'time',
#    'demonstrate',
#    'the',
#    'full',
#    'power',
#    'this',
#    'station.',
#    '(to',
#    'soldier)',
#    'set',
#    'your',
#    'course',
#    'for',
#    'princess',
#    "leia's",
#    'home',
#    'planet',
#    'alderaan.'],
#   'RED_LEADER'),
#  (['yes.'], 'RED_LEADER'),
#  (['oh,', "it's", 'nothing.', "don't", 'worry', 'about', 'it.'], 'TROOPER'),
#  (['are', 'they', 'away?'], 'RED_LEADER'),
#  (['come', 'out,', 'solo!'], 'JABBA'),
#  (['about', 'three', 'four', 'seasons.'], 'LUKE'),
#  (["i'm",
#    'here',
#    'rescue',
#    'you.',
#    "i've",
#    'got',
#    'your',
#    'unit.',
#    "i'm",
#    'here',
#    'with',
#    'ben',
#    'kenobi.'],
#   'LUKE'),
#  (["there's", 'something', 'alive', 'here!'], 'LUKE'),
#  (["we've", 'had', 'some', 'problems...'], 'THREEPIO'),
#  (['this',
#    'some',
#    'rescue.',
#    'when',
#    'you',
#    'came',
#    'here,',
#    "didn't",
#    'you',
#    'have',
#    'plan',
#    'for',
#    'getting',
#    'out?'],
#   'LEIA'),
#  (['what', 'piece', 'junk.'], 'LUKE'),
#  (['their', 'tracking', 'us!'], 'LEIA'),
#  (['help!',
#    'think',
#    "i'm",
#    'melting!',
#    '(to',
#    'artoo)',
#    'this',
#    'all',
#    'your',
#    'fault.'],
#   'THREEPIO'),
#  (['keep', 'your', 'eyes', 'open', 'for', 'those', 'fighters!'], 'RED_LEADER'),
#  (['not', 'can', 'help', 'it.', 'chewie...jam', "it's", 'transmissions.'],
#   'HAN'),
#  (['wake', 'up!', 'wake', 'up!'], 'THREEPIO'),
#  (['you', 'watch', 'your', 'language!'], 'THREEPIO')]

# %%
def get_words_in_tweets(train):
    all_words = []
    for (words, cclass) in train:
      all_words.extend(words)
    return all_words

def get_word_features(wordlist):
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
word_features = get_word_features(get_words_in_tweets(train))
len(word_features)
# Out:
# 1874

# %%
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
training_set = nltk.classify.apply_features(extract_features, train)
len(training_set)
# Out:
# 620

# %%
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
def train(labeled_featuresets, estimator=ELEProbDist):
        """
        :param labeled_featuresets: A list of classified featuresets,
            i.e., a list of tuples ``(featureset, label)``.
        """
        label_freqdist = FreqDist()
        feature_freqdist = defaultdict(FreqDist)
        feature_values = defaultdict(set)
        fnames = set()

        # Count up how many times each feature value occurred, given
        # the label and featurename.
        for featureset, label in labeled_featuresets:
            label_freqdist[label] += 1
            for fname, fval in featureset.items():
                # Increment freq(fval|label, fname)
                feature_freqdist[label, fname][fval] += 1
                # Record that fname can take the value fval.
                feature_values[fname].add(fval)
                # Keep a list of all feature names.
                fnames.add(fname)

        # If a feature didn't have a value given for an instance, then
        # we assume that it gets the implicit value 'None.'  This loop
        # counts up the number of 'missing' feature values for each
        # (label,fname) pair, and increments the count of the fval
        # 'None' by that amount.
        for label in label_freqdist:
            num_samples = label_freqdist[label]
            for fname in fnames:
                count = feature_freqdist[label, fname].N()
                # Only add a None key when necessary, i.e. if there are
                # any samples with feature 'fname' missing.
                if num_samples - count > 0:
                    feature_freqdist[label, fname][None] += num_samples - count
                    feature_values[fname].add(None)

        # Create the P(label) distribution
        label_probdist = estimator(label_freqdist)

        # Create the P(fval|label, fname) distribution
        feature_probdist = {}
        for ((label, fname), freqdist) in feature_freqdist.items():
            probdist = estimator(freqdist, bins=len(feature_values[fname]))
            feature_probdist[label, fname] = probdist

        return label_probdist, feature_probdist

# %%
label_probdist, feature_probdist = train(training_set, estimator=ELEProbDist)

# %%
for c in chars:
    print(c, label_probdist.prob(c))
# Out:
# LEIA 0.0728
# TROOPER 0.036
# LUKE 0.3272
# HAN 0.2008
# THREEPIO 0.1528
# VADER 0.052
# WEDGE 0.0008
# TARKIN 0.0008
# RED_LEADER 0.1016
# OFFICER 0.0136
# JABBA 0.0072
# BIGGS 0.036

# %%
#for c in chars:
#    print(c, feature_probdist[(c, 'contains(force)')].prob(True))

# %%
print( classifier.show_most_informative_features(10))
# Out:
# Most Informative Features
#          contains(doing) = True            JABBA : LUKE   =     41.0 : 1.0
#           contains(out,) = True            JABBA : LUKE   =     41.0 : 1.0
#           contains(give) = True            JABBA : LUKE   =     41.0 : 1.0
#           contains(only) = True            JABBA : LUKE   =     41.0 : 1.0
#           contains(rest) = True            JABBA : LUKE   =     41.0 : 1.0
#          contains(away.) = True            JABBA : LUKE   =     41.0 : 1.0
#           contains(best) = True            JABBA : LUKE   =     41.0 : 1.0
#            contains(put) = True            JABBA : LUKE   =     41.0 : 1.0
#          contains(short) = True            JABBA : HAN    =     25.2 : 1.0
#            contains(why) = True            JABBA : HAN    =     25.2 : 1.0
# None

# %%
testy = testx.apply(tuple, axis=1)
len(testy)

#testy
# Out:
# 155

# %%
df = []
for (words, cclass) in testy:
    testout = classifier.classify(extract_features(words.split()))
    df.append({'line': words, 'char': cclass, 'pred':
        testout})
        

predictions = pd.DataFrame(df)

# %%
predictions = predictions.sort_values('char')
char = list(predictions.char.unique())
char
# Out:
# ['BIGGS',
#  'HAN',
#  'JABBA',
#  'LEIA',
#  'LUKE',
#  'OFFICER',
#  'RED_LEADER',
#  'THREEPIO',
#  'TROOPER',
#  'VADER']

# %%
import itertools
from sklearn.metrics import  confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, export_graphviz
def plot_confusion_matrix(cm, classes,
                          title='x',
                          cmap=plt.cm.Blues):
    
 #   print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnc_matrix = confusion_matrix(predictions["char"], predictions["pred"])
np.set_printoptions(precision=2)

# Compute confusion matrix
#cns_matrix = confusion_matrix(X_test["Position"], y_predp)
#np.set_printoptions(precision=2)

# Plot 
plt.figure()
plot_confusion_matrix(cnc_matrix, classes=char,
                      title='Predict Char Line')


plt.show()

# Plot 
#plt.figure()
#plot_confusion_matrix(cnc_matrix, classes=pcnames,
#                     title='Predict Char Line')


#plt.show()
