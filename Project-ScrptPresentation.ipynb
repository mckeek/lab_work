# %% [markdown]
# # Using NBA player of the week data.
#
# Use scripting methods to transform and analyze the NBA Player of the week data taken from Kaggle. <br>
# The objective is to use concise and repeatable scripting methods to transform the dataset into something <br>
# that be used for graphing and analysis.
#
# Demonstrate the steps discussed in class <br>
# and produce a result that can be run, in a single pass, that will support analysis.
#
# From the Kaggle site the data is presented in a way that requires the analyst/programmer to transform the data prior to use. <br>
#
# One obvious example of this is: <br>
# Height and weight are in mixed formats. (ft-in/cm) (lb/kg) <br>
#
# In addition to the questions presented in the Kaggle Walkthrough article <br>
# Analysis questions were created and an attempt was made to discover the answers <br>
#
#
# ## Track through the Kaggle Walkthrough and create facts related to the Data.
#
# How has the bio statistics of NBA players changed over the years? <br>
# Can we use the historical data to predict the player position based on bio statistics?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### Transformation and Feature Extraction
# Bucketing - Combining similar values to make the data more relatable
# Normalization - converting the values of a column into a ‘normalized’ range.
#
# ### Pick an Algorithm
# Cross Validation
# Tuning and Predictions

# %%
#https://www.kaggle.com/jacobbaruch/nba-player-of-the-week

import pandas as pd
import numpy as np
import csv 
from matplotlib import pyplot as plot
import seaborn as sns
import matplotlib
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.metrics import  confusion_matrix
import matplotlib.pyplot as plt
import itertools

# split first middle last
#split team neame
#split date 
#remove column

# %%
bbfile = '/Users/kenmckee/Desktop/GS/F18/Scrpt/KMCKEE_HW1/NBA_player_of_the_week.csv'

# %% [markdown]
# #### How many records (rows) have been provided?

# %%
#You may choose a dataset to work with.  
#As a guideline, datasets should be chosen that have somewhere between 500 and 4,000 lines of data 
#with some number of columns between 4 and 50.  
#These guidelines are not exact limits, just guidance for selecting data.


bbdf = pd.read_csv(bbfile)

#print(bbdf)
bbdf.shape
# Out:
# (1145, 13)

# %% [markdown]
# ### Kaggle Part two suggests we should check the following.
#
# So far we know.
# What features (columns) does the dataset contain?
# NBA Player of the Week Records 1988 to 2018
#
# How many records (rows) have been provided?
# 1145X13 Matrix
#
# We will look at the dataset further to find the following.
#
# What format is the data in (e.g. what format are the dates provided, are there numerical values, what do the different categorical values look like)?
#
# Are there missing values?
#
# How do the different features relate to each other?

# %% [markdown]
# ## Understand Data
# #### A list of all "player of the week" recipients from 1985 to 2018.
#
# #### What features (columns) does the dataset contain?

# %%
#bbdf.Conference.unique()

bbdf.isnull().sum()
# Out:
# Age                    0
# Conference           384
# Date                   0
# Draft Year             0
# Height                 0
# Player                 0
# Position               0
# Season                 0
# Season short           0
# Seasons in league      0
# Team                   0
# Weight                 0
# Real_value             0
# dtype: int64

# %% [markdown]
# ### How many different players are there

# %% [markdown]
# ### 384 of 1145 observations are Null in the conference column ..
# #### We will take a look and decide what the problem is

# %%
bbdf.Player.unique()
# Out:
# array(['Micheal Ray Richardson', 'Derek Smith', 'Calvin Natt',
#        'Kareem Abdul-Jabbar', 'Larry Bird', 'Darrell Griffith',
#        'Sleepy Floyd', 'Mark Aguirre', 'Magic Johnson',
#        'Dominique Wilkins', 'Tom McMillen', 'Michael Jordan',
#        'World B. Free', 'Isiah Thomas', 'Terry Cummings',
#        'Orlando Woolridge', 'Jack Sikma', 'Bernard King', 'Moses Malone',
#        'Alex English', 'Larry Nance', 'Herb Williams', 'Charles Barkley',
#        'Adrian Dantley', 'Sidney Moncrief', 'Clyde Drexler',
#        'Alvin Robertson', 'Jeff Ruland', 'Patrick Ewing', 'Buck Williams',
#        'Julius Erving', 'Larry Smith', 'Karl Malone', 'Fat Lever',
#        'Otis Thorpe', 'Tom Chambers', 'Hot Rod Williams', 'Robert Parish',
#        'Harold Pressley', 'Bobby Hansen', 'Roy Tarpley', 'John Stockton',
#        'Byron Scott', 'Xavier McDaniel', 'Kevin Johnson', 'Chuck Person',
#        'Hakeem Olajuwon', 'Ron Harper', 'Chris Mullin', 'Dale Ellis',
#        'Michael Adams', 'David Robinson', 'Rony Seikaly', 'Tim Hardaway',
#        'Terry Teagle', 'Vern Fleming', 'Scott Skiles', 'Mitch Richmond',
#        'Kenny Smith', 'Dennis Scott', 'Gerald Wilkins', 'Reggie Miller',
#        'Lionel Simmons', 'Ricky Pierce', 'Reggie Lewis',
#        'Mookie Blaylock', 'Mark Jackson', 'Larry Johnson', 'Joe Dumars',
#        'Danny Manning', 'Nick Anderson', 'Scottie Pippen',
#        'Pervis Ellison', 'Dennis Rodman', 'Jeff Malone', 'Kevin Willis',
#        'Brad Daugherty', 'Alonzo Mourning', 'Dikembe Mutombo',
#        'Rumeal Robinson', 'Shawn Kemp', 'Sean Elliott', 'Drazen Petrovic',
#        "Shaquille O'Neal", 'Kenny Anderson', 'Chris Webber',
#        'Oliver Miller', 'Glen Rice', 'Vlade Divac', 'Jason Kidd',
#        'Rik Smits', 'Rod Strickland', 'Gary Payton', 'Cedric Ceballos',
#        'Jamal Mashburn', 'Penny Hardaway', 'Elliot Perry', 'Juwan Howard',
#        'Arvydas Sabonis', 'Chris Gatling', 'Grant Hill', 'Armen Gilliam',
#        'Cliff Robinson', 'Terrell Brandon', 'Allen Iverson', 'Loy Vaught',
#        'Glenn Robinson', 'Terry Mills', 'Sam Cassell', 'Tim Duncan',
#        'Jayson Williams', 'Steve Smith', 'Wesley Person', 'Kevin Garnett',
#        'Darrell Armstrong', 'Vince Carter', 'Antonio McDyess',
#        'Stephon Marbury', 'Kobe Bryant', 'Jalen Rose', 'Michael Finley',
#        'Steve Francis', 'Ray Allen', 'Paul Pierce', 'Cuttino Mobley',
#        'Derek Anderson', 'Shawn Marion', 'Aaron McKie', 'Baron Davis',
#        'Ben Wallace', 'Tracy McGrady', 'Kurt Thomas', 'Rasheed Wallace',
#        'Andre Miller', 'Dirk Nowitzki', 'Eddie Jones', "Jermaine O'Neal",
#        'Richard Hamilton', 'Steve Nash', 'Elton Brand',
#        'Shareef Abdur-Rahim', 'Richard Jefferson', 'Peja Stojakovic',
#        'Allan Houston', 'Chauncey Billups', 'Antoine Walker',
#        'Lucious Harris', 'Metta World Peace', 'Rashard Lewis',
#        'Jerry Stackhouse', 'Jamaal Magloire', 'Carmelo Anthony',
#        'Zydrunas Ilgauskas', 'Lamar Odom', 'Yao Ming', 'Andrei Kirilenko',
#        'Dwyane Wade', 'Kenyon Martin', 'Carlos Boozer', 'Voshon Lenard',
#        'Quentin Richardson', 'Jason Richardson', 'Marcus Camby',
#        'Mike Bibby', 'Brad Miller', 'LeBron James', 'Jason Terry',
#        'Larry Hughes', 'Chris Bosh', 'Bruce Bowen', 'Pau Gasol',
#        "Amar'e Stoudemire", 'Gilbert Arenas', 'Ben Gordon',
#        'Jamal Crawford', 'Chris Wilcox', 'Tony Parker', 'Chris Paul',
#        'Mike James', 'Joe Johnson', 'Gerald Wallace', 'T.J. Ford',
#        'Manu Ginobili', 'Al Jefferson', 'Kevin Martin', 'Mehmet Okur',
#        'Caron Butler', 'Michael Redd', 'Josh Howard', 'Mo Williams',
#        'Dwight Howard', 'Antawn Jamison', 'Hedo Turkoglu', 'Brandon Roy',
#        'Josh Smith', 'Stephen Jackson', 'Danny Granger', 'Deron Williams',
#        'Devin Harris', 'David West', 'David Lee', 'Andrew Bynum',
#        'Jameer Nelson', 'Rodney Stuckey', 'Al Harrington', 'Kevin Durant',
#        'Andrew Bogut', 'Russell Westbrook', 'Chris Kaman', 'Derrick Rose',
#        'Brandon Jennings', 'Zach Randolph', 'Kyle Lowry',
#        'LaMarcus Aldridge', 'Monta Ellis', 'Rajon Rondo', 'Goran Dragic',
#        'Drew Gooden', 'Ersan Ilyasova', 'Ty Lawson', 'Jeremy Lin',
#        'Marc Gasol', 'Nikola Pekovic', 'J.R. Smith', 'James Harden',
#        'John Wall', 'Nate Robinson', 'Kyrie Irving', 'Greivis Vasquez',
#        'Paul George', 'Blake Griffin', 'Al Horford', 'Kenneth Faried',
#        'Jeff Teague', 'Nikola Vucevic', 'Kemba Walker', 'Kevin Love',
#        'Jared Sullinger', 'Paul Millsap', 'DeMarcus Cousins',
#        'Thaddeus Young', 'Jordan Crawford', 'Markieff Morris',
#        'Michael Carter-Williams', 'Isaiah Thomas', 'Brook Lopez',
#        'Stephen Curry', 'Anthony Davis', 'Damian Lillard',
#        'Giannis Antetokounmpo', 'Klay Thompson', 'Jimmy Butler',
#        'Lou Williams', 'Karl-Anthony Towns', 'J.J. Barea',
#        'Kawhi Leonard', 'Draymond Green', 'Marcin Gortat',
#        'Reggie Jackson', 'DeMar DeRozan', 'Nicolas Batum',
#        'Andre Drummond', 'Hassan Whiteside', 'Dion Waiters',
#        'Joel Embiid', 'Gordon Hayward', 'George Hill', 'Ben Simmons',
#        'Nikola Jokic', 'Victor Oladipo', 'Khris Middleton',
#        'Bradley Beal', 'Tobias Harris', 'Kristaps Porzingis'],
#       dtype=object)

# %% [markdown]
# #### This format is probably ok for what the objective is but we should split the column all the same
# We will add that to the list for reshaping and reforming the data.

# %%
pu = bbdf.Player.unique()
print(len(pu))

print(1145/274)
# Out:
# 274
# 4.178832116788321

# %% [markdown]
# #### 1145 records with 274 Unique player names. (that's averages out to four records per player)
# First we will check for nulls and decide what to do with the other column formats

# %%
print(bbdf)
# Out:
#       Age Conference          Date  Draft Year Height                  Player  \
# 0      29        NaN  Apr 14, 1985        1978    6-5  Micheal Ray Richardson
# 1      23        NaN   Apr 7, 1985        1982    6-6             Derek Smith
# 2      28        NaN   Apr 1, 1985        1979    6-6             Calvin Natt
# 3      37        NaN  Mar 24, 1985        1969    7-2     Kareem Abdul-Jabbar
# 4      28        NaN  Mar 17, 1985        1978    6-9              Larry Bird
# 5      26        NaN  Mar 10, 1985        1980    6-4        Darrell Griffith
# 6      24        NaN   Mar 3, 1985        1982    6-3            Sleepy Floyd
# 7      25        NaN  Feb 24, 1985        1981    6-6            Mark Aguirre
# 8      25        NaN  Feb 17, 1985        1979    6-9           Magic Johnson
# 9      25        NaN   Feb 3, 1985        1982    6-7       Dominique Wilkins
# 10     32        NaN  Jan 27, 1985        1974   6-11            Tom McMillen
# 11     22        NaN  Jan 20, 1985        1984    6-6          Michael Jordan
# 12     31        NaN  Jan 13, 1985        1975    6-2           World B. Free
# 13     23        NaN   Jan 6, 1985        1981    6-1            Isiah Thomas
# 14     29        NaN  Dec 30, 1984        1978    6-5  Micheal Ray Richardson
# 15     23        NaN  Dec 23, 1984        1982    6-9          Terry Cummings
# 16     23        NaN  Dec 16, 1984        1982    6-6             Derek Smith
# 17     25        NaN   Dec 9, 1984        1981    6-9       Orlando Woolridge
# 18     29        NaN   Dec 2, 1984        1977   6-11              Jack Sikma
# 19     28        NaN  Nov 25, 1984        1977    6-7            Bernard King
# 20     29        NaN  Nov 18, 1984        1976   6-10            Moses Malone
# 21     31        NaN  Nov 11, 1984        1976    6-7            Alex English
# 22     26        NaN   Nov 4, 1984        1981   6-10             Larry Nance
# 23     26        NaN  Apr 13, 1986        1982    6-7       Dominique Wilkins
# 24     28        NaN   Apr 6, 1986        1981   6-10           Herb Williams
# 25     23        NaN  Mar 30, 1986        1984    6-6         Charles Barkley
# 26     30        NaN  Mar 23, 1986        1976    6-5          Adrian Dantley
# 27     29        NaN  Mar 16, 1986        1978    6-9              Larry Bird
# 28     26        NaN   Mar 9, 1986        1979    6-9           Magic Johnson
# 29     23        NaN   Mar 2, 1986        1984    6-6         Charles Barkley
# ...   ...        ...           ...         ...    ...                     ...
# 1115   26       East  Jan 29, 2018        2012  203cm         Khris Middleton
# 1116   29       West  Jan 29, 2018        2009  191cm           Stephen Curry
# 1117   23       East  Jan 22, 2018        2014  213cm             Joel Embiid
# 1118   27       West  Jan 22, 2018        2012  191cm          Damian Lillard
# 1119   31       East  Jan 15, 2018        2008  191cm            Goran Dragic
# 1120   31       West  Jan 15, 2018        2005  185cm            Lou Williams
# 1121   28       East   Jan 8, 2018        2009  201cm           DeMar DeRozan
# 1122   29       West   Jan 8, 2018        2009  191cm           Stephen Curry
# 1123   24       East   Jan 2, 2018        2012  196cm            Bradley Beal
# 1124   31       West   Jan 2, 2018        2005  185cm            Lou Williams
# 1125   28       East  Dec 26, 2017        2009  201cm           DeMar DeRozan
# 1126   29       West  Dec 26, 2017        2008  191cm       Russell Westbrook
# 1127   33       East  Dec 18, 2017        2003  203cm            LeBron James
# 1128   32       West  Dec 18, 2017        2005  183cm              Chris Paul
# 1129   25       East  Dec 11, 2017        2013  193cm          Victor Oladipo
# 1130   29       West  Dec 11, 2017        2007  206cm            Kevin Durant
# 1131   33       East   Dec 4, 2017        2003  203cm            LeBron James
# 1132   28       West   Dec 4, 2017        2009  196cm            James Harden
# 1133   31       East  Nov 27, 2017        2008  191cm            Goran Dragic
# 1134   24       West  Nov 27, 2017        2012  208cm           Anthony Davis
# 1135   28       East  Nov 20, 2017        2009  201cm           DeMar DeRozan
# 1136   22       West  Nov 20, 2017        2015  213cm      Karl-Anthony Towns
# 1137   25       East  Nov 13, 2017        2011  206cm           Tobias Harris
# 1138   23       West  Nov 13, 2017        2014  208cm            Nikola Jokic
# 1139   22       East   Nov 6, 2017        2015  221cm      Kristaps Porzingis
# 1140   28       West   Nov 6, 2017        2009  196cm            James Harden
# 1141   25       East  Oct 30, 2017        2013  193cm          Victor Oladipo
# 1142   27       West  Oct 30, 2017        2010  211cm        DeMarcus Cousins
# 1143   23       East  Oct 23, 2017        2013  211cm   Giannis Antetokounmpo
# 1144   28       West  Oct 23, 2017        2009  196cm            James Harden
#
#      Position     Season  Season short  Seasons in league  \
# 0          PG  1984-1985          1985                  6
# 1          SG  1984-1985          1985                  2
# 2           F  1984-1985          1985                  5
# 3           C  1984-1985          1985                 15
# 4          SF  1984-1985          1985                  5
# 5          SG  1984-1985          1985                  4
# 6          PG  1984-1985          1985                  2
# 7          SF  1984-1985          1985                  3
# 8          PG  1984-1985          1985                  5
# 9          SF  1984-1985          1985                  2
# 10         PF  1984-1985          1985                  9
# 11         SG  1984-1985          1985                  0
# 12          G  1984-1985          1985                  9
# 13         PG  1984-1985          1985                  3
# 14         PG  1984-1985          1985                  6
# 15         PF  1984-1985          1985                  2
# 16         SG  1984-1985          1985                  2
# 17         PF  1984-1985          1985                  3
# 18          C  1984-1985          1985                  7
# 19         SF  1984-1985          1985                  7
# 20          C  1984-1985          1985                  8
# 21         SF  1984-1985          1985                  8
# 22         PF  1984-1985          1985                  3
# 23         SF  1985-1986          1986                  3
# 24          C  1985-1986          1986                  4
# 25         PF  1985-1986          1986                  1
# 26         SF  1985-1986          1986                  9
# 27         SF  1985-1986          1986                  6
# 28         PG  1985-1986          1986                  6
# 29         PF  1985-1986          1986                  1
# ...       ...        ...           ...                ...
# 1115       SF  2017-2018          2018                  5
# 1116        G  2017-2018          2018                  8
# 1117        C  2017-2018          2018                  3
# 1118        G  2017-2018          2018                  5
# 1119        G  2017-2018          2018                  9
# 1120        G  2017-2018          2018                 12
# 1121       GF  2017-2018          2018                  8
# 1122        G  2017-2018          2018                  8
# 1123       SG  2017-2018          2018                  5
# 1124        G  2017-2018          2018                 12
# 1125       GF  2017-2018          2018                  8
# 1126        G  2017-2018          2018                  9
# 1127        F  2017-2018          2018                 14
# 1128       PG  2017-2018          2018                 12
# 1129        G  2017-2018          2018                  4
# 1130       SF  2017-2018          2018                 10
# 1131        F  2017-2018          2018                 14
# 1132       SG  2017-2018          2018                  8
# 1133        G  2017-2018          2018                  9
# 1134       PF  2017-2018          2018                  5
# 1135       GF  2017-2018          2018                  8
# 1136        C  2017-2018          2018                  2
# 1137        F  2017-2018          2018                  6
# 1138        C  2017-2018          2018                  2
# 1139       FC  2017-2018          2018                  2
# 1140       SG  2017-2018          2018                  8
# 1141        G  2017-2018          2018                  4
# 1142        C  2017-2018          2018                  7
# 1143        F  2017-2018          2018                  4
# 1144       SG  2017-2018          2018                  8
#
#                         Team Weight  Real_value
# 0            New Jersey Nets    189         1.0
# 1       Los Angeles Clippers    205         1.0
# 2             Denver Nuggets    220         1.0
# 3         Los Angeles Lakers    225         1.0
# 4             Boston Celtics    220         1.0
# 5                  Utah Jazz    190         1.0
# 6      Golden State Warriors    170         1.0
# 7           Dallas Mavericks    232         1.0
# 8         Los Angeles Lakers    255         1.0
# 9              Atlanta Hawks    200         1.0
# 10        Washington Bullets    215         1.0
# 11             Chicago Bulls    215         1.0
# 12       Cleveland Cavaliers    185         1.0
# 13           Detroit Pistons    180         1.0
# 14           New Jersey Nets    189         1.0
# 15           Milwaukee Bucks    220         1.0
# 16      Los Angeles Clippers    205         1.0
# 17             Chicago Bulls    215         1.0
# 18       Seattle SuperSonics    230         1.0
# 19           New York Knicks    205         1.0
# 20       Philadelphia Sixers    215         1.0
# 21            Denver Nuggets    190         1.0
# 22              Phoenix Suns    205         1.0
# 23             Atlanta Hawks    200         1.0
# 24            Indiana Pacers    242         1.0
# 25       Philadelphia Sixers    252         1.0
# 26                 Utah Jazz    208         1.0
# 27            Boston Celtics    220         1.0
# 28        Los Angeles Lakers    255         1.0
# 29       Philadelphia Sixers    252         1.0
# ...                      ...    ...         ...
# 1115         Milwaukee Bucks  106kg         0.5
# 1116   Golden State Warriors   86kg         0.5
# 1117     Philadelphia Sixers  113kg         0.5
# 1118  Portland Trail Blazers   88kg         0.5
# 1119              Miami Heat   86kg         0.5
# 1120    Los Angeles Clippers   79kg         0.5
# 1121         Toronto Raptors  100kg         0.5
# 1122   Golden State Warriors   86kg         0.5
# 1123      Washington Wizards   94kg         0.5
# 1124    Los Angeles Clippers   79kg         0.5
# 1125         Toronto Raptors  100kg         0.5
# 1126   Oklahoma City Thunder   91kg         0.5
# 1127     Cleveland Cavaliers  113kg         0.5
# 1128         Houston Rockets   79kg         0.5
# 1129          Indiana Pacers   95kg         0.5
# 1130   Golden State Warriors  109kg         0.5
# 1131     Cleveland Cavaliers  113kg         0.5
# 1132         Houston Rockets  100kg         0.5
# 1133              Miami Heat   86kg         0.5
# 1134    New Orleans Pelicans  115kg         0.5
# 1135         Toronto Raptors  100kg         0.5
# 1136  Minnesota Timberwolves  111kg         0.5
# 1137         Detroit Pistons  107kg         0.5
# 1138          Denver Nuggets  113kg         0.5
# 1139         New York Knicks  109kg         0.5
# 1140         Houston Rockets  100kg         0.5
# 1141          Indiana Pacers   95kg         0.5
# 1142    New Orleans Pelicans  122kg         0.5
# 1143         Milwaukee Bucks  101kg         0.5
# 1144         Houston Rockets  100kg         0.5
#
# [1145 rows x 13 columns]

# %% [markdown]
# ### Kaggle Walkthrough Part Three Cleaning Data
# Article suggests we either fix or ignore the missing and misformatted datat <br>
# The data needs to be put into a state that can be analyzed for bio metrics <br>
# If we can fix the data we will.
#
# We are going to assume that, in the future, name and team will need to be used in analysis <br>
#
#
# ### This is a list of tasks for fixing the data
# Split first and last name  - use  a string split on the first space to the left from the end <br>
# Split city and team name - same process <br>
# Fill in Conference values - Did a little research and found the correct conference per year and filled <br>
# the data in for the given team name.
#
# ### The important ones.
# Height was partially in feet-inches and partially in centimeters. F-I and XXcm <br>
# Weight was in pounds and kilograms XXX and XXkg
#
# #### Method
# split off the numeric from the alpha <br>
# for F-I height split feet from inches on the dash and create F and I columns

# %% [markdown]
# ### use str.split to divide the string on the first space from the right.
# assign the two separate strings to new columns. <br>
#
# bbdf['Last-Name'] = bbdf['Player'].str.rsplit(' ',1).str[1]

# %%
bbdf['Last-Name'] = bbdf['Player'].str.rsplit(' ',1).str[1]
bbdf['First-Name'] = bbdf['Player'].str.rsplit(' ',1).str[0]

# %% [markdown]
# ### Show the frequency of Player Last Name in the Dataset

# %%
pcounts = bbdf['Last-Name'].value_counts()



print(pcounts[:5])
# Out:
# James      62
# Bryant     33
# Johnson    28
# Durant     26
# Malone     26
# Name: Last-Name, dtype: int64

# %% [markdown]
# ### Split Team name and City
# Rename Season Short to SSeason

# %%
#s.rsplit(";", 3)

bbdf['TeamName'] = bbdf['Team'].str.rsplit(' ',1).str[1]
bbdf['City'] = bbdf['Team'].str.rsplit(' ',1).str[0]
bbdf = bbdf.drop(['Season'],axis=1)
bbdf['SSeason'] = bbdf['Season short']
bbdf = bbdf.drop(['Season short'],axis=1)

# %% [markdown]
# #### What is the frequency of the top ten team names in the dataset?
#
# .value_counts() will summarize the dataframe based on column in this case

# %%
#find the team with the most players in the population

from matplotlib import pyplot as plot
import numpy as np
pcounts = bbdf['TeamName'].value_counts()



print(pcounts[:10])
# Out:
# Lakers       71
# Spurs        61
# Cavaliers    59
# Heat         57
# Rockets      56
# Jazz         47
# Suns         45
# Magic        44
# Warriors     44
# Bulls        44
# Name: TeamName, dtype: int64

# %% [markdown]
# #### Find Null Conference observations
#
# #### Create a list of unique Team names  where the conference is missing

# %%
bbdfn = bbdf[bbdf['Conference'].isnull()]
bbdfnt = bbdfn.TeamName.unique()

print(bbdfnt)

#for t in bbdfnt:
#    c = bbdf.loc[bbdf['TeamName'] == t, 'Conference']
#    print(t,c)
# Out:
# ['Nets' 'Clippers' 'Nuggets' 'Lakers' 'Celtics' 'Jazz' 'Warriors'
#  'Mavericks' 'Hawks' 'Bullets' 'Bulls' 'Cavaliers' 'Pistons' 'Bucks'
#  'SuperSonics' 'Knicks' 'Sixers' 'Suns' 'Pacers' 'Blazers' 'Spurs' 'Kings'
#  'Rockets' 'Heat' 'Magic' 'Hornets' 'Timberwolves' 'Raptors']

# %% [markdown]
# #### The Null in Conference is illustrated here

# %%
print(bbdfn.loc[[379]])
# Out:
#      Age Conference          Date  Draft Year Height       Player Position  \
# 379   21        NaN  Nov 26, 2000        1999    6-3  Baron Davis        G
#
#      Seasons in league               Team Weight  Real_value Last-Name  \
# 379                  1  Charlotte Hornets    215         1.0     Davis
#
#     First-Name TeamName       City  SSeason
# 379      Baron  Hornets  Charlotte     2001

# %% [markdown]
# #### Create our lists for the desired conference

# %%
west = bbdf['TeamName'][bbdf['Conference']=='West']
east = bbdf['TeamName'][bbdf['Conference']=='East']
#east = list(bbdf.loc[bbdf['Conference'] == 'East'])

print(west.unique())
print(east.unique())
#print(east)
# Out:
# ['Spurs' 'Suns' 'Lakers' 'Blazers' 'Jazz' 'Mavericks' 'Timberwolves'
#  'Kings' 'SuperSonics' 'Clippers' 'Rockets' 'Nuggets' 'Warriors'
#  'Grizzlies' 'Hornets' 'Thunder' 'Pelicans']
# ['Celtics' 'Pistons' 'Nets' 'Magic' 'Knicks' 'Sixers' 'Cavaliers' 'Bucks'
#  'Heat' 'Pacers' 'Wizards' 'Hawks' 'Raptors' 'Hornets' 'Bulls' 'Bobcats'
#  'Clippers']

# %%
WEST = ('Clippers','Nuggets','Lakers','Jazz','Warriors','Mavericks','Supersonics','Suns','Blazers','Spurs','Kings','Rockets','Timberwolves',)
EAST = ('Nets','Celtics','Hawks','Bullets','Bulls','Cavaliers','Pistions','Bucks','Knicks','Sixers','Pacers','Heat','Magic','Raptors', 'Hornets')

# %% [markdown]
# #### Use the where is in function to assign conference names in the dataset
# #### One for East and one for West.

# %%
bbdf['Conference'] = np.where(bbdf.TeamName.isin(['Nets','Celtics','Hawks','Bullets','Bulls','Cavaliers',
                                                  'Pistions','Bucks','Knicks','Sixers','Pacers','Heat',
                                                  'Magic','Raptors', 'Hornets','Pistons']),'East', bbdf['Conference'])
#print(bbdf)

# %%
bbdf['Conference'] = np.where(bbdf.TeamName.isin(['Clippers','Nuggets','Lakers','Jazz','Warriors',
                                                  'Mavericks','SuperSonics','Suns','Blazers','Spurs',
                                                  'Kings','Rockets','Timberwolves']),'West', bbdf['Conference'])
#print(bbdf)

# %% [markdown]
# ### Check for Nulls and it looks like it worked.
# bbdfn = bbdf[bbdf['Conference'].isnull()]
#
# If the function failed this would return a result greater than zero.

# %%
bbdfn = bbdf[bbdf['Conference'].isnull()]
bbdfnt = bbdfn.TeamName.unique()

print(bbdfnt)

for t in bbdfnt:
    c = bbdf.loc[bbdf['TeamName'] == t, 'Conference']
    print(t,c)
# Out:
# []

# %% [markdown]
# ### Work on the Height Column.
#
# Split CM from the string usint str.split
# move the numeric to a new Inches column and create a marker called htype when cm is encountered.
#
# We will use this later to decide how to convert all the data to feet and inches.
#
# The observations that are F-I are then split on the dash using str.split where htype is null
# Create a feet column and populate Feet with F and I with Inches
#
# isnull and notnull was the function that was used to distinguish the different height and weight values <br>
# if the operation was executed on the row a marker was added and, if not, the field was left null <br>
# in this was it was possible to keep track of which records were different <br>
#
# There are many ways to do this and this one is probably not the most effiecient. <br>
# The process does a very clear job of demonstrating how text.split can be used to transform data.
#
# When using expand=True, the split elements will expand out into separate columns

# %%
bbdf['inches'] = 0
bbdf[['inches','htype']] = bbdf['Height'].str.split('cm', expand=True)
#print(bbdf['htype'])

# %% [markdown]
# #### It probably wasn't necessary to initialize 'feet' but it never hurts.
#
# When htype is null (feet and inches) split 'Height' on the dash and assign the F portion to a column called 'feet' <br>
# and set the right side to inches <br>
#
# This is an interesting format for running this process

# %%
bbdf['feet'] = 0
bbdf.feet[bbdf['htype'].isnull()] , bbdf.inches[bbdf['htype'].isnull()] = bbdf['Height'].str.split('-', 1).str


#print(bbdf['inches'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# ### Now apply the math to obtain the total inches for each record
#
# Combine feet and inches for total inches
# Where CM is flagged - multiply inches by .393701
#
# The process demonstrates mathmatical transformation. <br>
# Create a column called nheight (new height) so we can verify the result against the <br>
# provided data.

# %%
bbdf['inches'] = (bbdf['feet'].astype(int) * 12) + (bbdf['inches'].astype(int))

bbdf.inches[bbdf['htype'].notnull()] = (bbdf['inches'].astype(float)*0.393701)


#print(bbdf['feet'], bbdf['htype'])
#print(bbdf['feet'])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Divide inches by 12 and populate new height

# %%
bbdf['nheight'] = bbdf['inches'].astype(float)/12
bbdf['nheight'] = bbdf.nheight.round(2)

#print(bbdf['nheight'])

# %% [markdown]
# ### Compare the two columns.
#
# The Zip function can combine two lists for convenience.
#
# This is a very light example of normalization
# using base 10 for height instead of base 12

# %%
hcomp = bbdf['Height']
hcompn = bbdf['nheight']

for h, nh in zip(hcomp, hcompn):
    print(h,nh)
# Out:
# 6-5 6.42
# 6-6 6.5
# 6-6 6.5
# 7-2 7.17
# 6-9 6.75
# 6-4 6.33
# 6-3 6.25
# 6-6 6.5
# 6-9 6.75
# 6-7 6.58
# 6-11 6.92
# 6-6 6.5
# 6-2 6.17
# 6-1 6.08
# 6-5 6.42
# 6-9 6.75
# 6-6 6.5
# 6-9 6.75
# 6-11 6.92
# 6-7 6.58
# 6-10 6.83
# 6-7 6.58
# 6-10 6.83
# 6-7 6.58
# 6-10 6.83
# 6-6 6.5
# 6-5 6.42
# 6-9 6.75
# 6-9 6.75
# 6-6 6.5
# 6-3 6.25
# 6-9 6.75
# 6-7 6.58
# 6-6 6.5
# 6-9 6.75
# 6-6 6.5
# 6-7 6.58
# 6-7 6.58
# 6-10 6.83
# 6-3 6.25
# 6-10 6.83
# 6-9 6.75
# 6-7 6.58
# 7-0 7.0
# 6-8 6.67
# 6-6 6.5
# 6-6 6.5
# 6-6 6.5
# 6-9 6.75
# 6-8 6.67
# 6-9 6.75
# 6-9 6.75
# 6-9 6.75
# 6-6 6.5
# 6-10 6.83
# 6-9 6.75
# 6-3 6.25
# 6-7 6.58
# 6-9 6.75
# 6-1 6.08
# 6-9 6.75
# 7-0 7.0
# 6-9 6.75
# 6-7 6.58
# 6-10 6.83
# 6-11 6.92
# 6-3 6.25
# 7-0 7.0
# 6-6 6.5
# 6-9 6.75
# 6-3 6.25
# 6-7 6.58
# 6-6 6.5
# 6-6 6.5
# 6-6 6.5
# 6-7 6.58
# 6-6 6.5
# 6-11 6.92
# 6-1 6.08
# 6-7 6.58
# 6-7 6.58
# 6-6 6.5
# 6-7 6.58
# 6-3 6.25
# 6-9 6.75
# 6-7 6.58
# 6-10 6.83
# 6-9 6.75
# 6-7 6.58
# 6-7 6.58
# 6-7 6.58
# 6-9 6.75
# 6-7 6.58
# 6-9 6.75
# 6-7 6.58
# 6-6 6.5
# 6-6 6.5
# 6-1 6.08
# 6-1 6.08
# 6-8 6.67
# 7-0 7.0
# 7-0 7.0
# 6-6 6.5
# 6-10 6.83
# 6-7 6.58
# 6-6 6.5
# 6-7 6.58
# 6-9 6.75
# 6-7 6.58
# 7-0 7.0
# 5-10 5.83
# 6-9 6.75
# 7-0 7.0
# 6-6 6.5
# 7-0 7.0
# 7-1 7.08
# 6-9 6.75
# 6-6 6.5
# 6-6 6.5
# 7-1 7.08
# 6-1 6.08
# 6-11 6.92
# 7-0 7.0
# 7-1 7.08
# 6-10 6.83
# 6-0 6.0
# 6-9 6.75
# 6-3 6.25
# 6-6 6.5
# 6-5 6.42
# 6-9 6.75
# 6-9 6.75
# 6-7 6.58
# 6-6 6.5
# 7-0 7.0
# 6-7 6.58
# 6-1 6.08
# 6-5 6.42
# 6-1 6.08
# 6-7 6.58
# 6-9 6.75
# 6-7 6.58
# 6-5 6.42
# 6-3 6.25
# 6-8 6.67
# 6-6 6.5
# 6-7 6.58
# 6-7 6.58
# 6-9 6.75
# 5-10 5.83
# 6-0 6.0
# 6-7 6.58
# 6-7 6.58
# 6-4 6.33
# 6-6 6.5
# 6-1 6.08
# 6-1 6.08
# 6-6 6.5
# 6-6 6.5
# 6-7 6.58
# 6-7 6.58
# 6-9 6.75
# 6-7 6.58
# 6-1 6.08
# 6-1 6.08
# 6-6 6.5
# 6-3 6.25
# 6-9 6.75
# 6-10 6.83
# 6-0 6.0
# 6-1 6.08
# 6-10 6.83
# 6-6 6.5
# 6-0 6.0
# 6-6 6.5
# 7-0 7.0
# 6-8 6.67
# 6-9 6.75
# 6-7 6.58
# 6-4 6.33
# 7-1 7.08
# 7-0 7.0
# 7-0 7.0
# 6-7 6.58
# 6-6 6.5
# 6-10 6.83
# 7-0 7.0
# 6-6 6.5
# 7-2 7.17
# 7-0 7.0
# 6-2 6.17
# 6-11 6.92
# 7-0 7.0
# 6-6 6.5
# 6-6 6.5
# 6-9 6.75
# 7-0 7.0
# 7-0 7.0
# 6-10 6.83
# 7-1 7.08
# 6-8 6.67
# 7-0 7.0
# 6-6 6.5
# 6-5 6.42
# 7-1 7.08
# 6-6 6.5
# 7-1 7.08
# 7-1 7.08
# 6-8 6.67
# 7-2 7.17
# 6-10 6.83
# 7-0 7.0
# 7-0 7.0
# 6-3 6.25
# 7-1 7.08
# 6-10 6.83
# 7-1 7.08
# 7-1 7.08
# 6-6 6.5
# 6-0 6.0
# 7-0 7.0
# 6-9 6.75
# 6-9 6.75
# 6-8 6.67
# 6-9 6.75
# 7-1 7.08
# 7-1 7.08
# 6-8 6.67
# 6-6 6.5
# 7-0 7.0
# 6-9 6.75
# 7-2 7.17
# 6-7 6.58
# 7-1 7.08
# 7-1 7.08
# 6-4 6.33
# 7-4 7.33
# 7-1 7.08
# 6-3 6.25
# 6-6 6.5
# 7-0 7.0
# 6-1 6.08
# 7-0 7.0
# 6-6 6.5
# 6-4 6.33
# 7-0 7.0
# 6-6 6.5
# 6-9 6.75
# 6-8 6.67
# 7-1 7.08
# 6-7 6.58
# 6-0 6.0
# 6-0 6.0
# 6-8 6.67
# 6-9 6.75
# 6-1 6.08
# 7-3 7.25
# 6-10 6.83
# 6-8 6.67
# 6-6 6.5
# 7-1 7.08
# 7-0 7.0
# 6-10 6.83
# 6-9 6.75
# 6-4 6.33
# 6-7 6.58
# 6-6 6.5
# 7-1 7.08
# 6-10 6.83
# 6-9 6.75
# 6-6 6.5
# 6-8 6.67
# 7-2 7.17
# 5-11 5.92
# 6-10 6.83
# 6-6 6.5
# 6-7 6.58
# 6-9 6.75
# 6-0 6.0
# 6-8 6.67
# 6-1 6.08
# 6-9 6.75
# 6-9 6.75
# 7-0 7.0
# 6-9 6.75
# 6-8 6.67
# 6-10 6.83
# 6-8 6.67
# 6-5 6.42
# 6-8 6.67
# 6-7 6.58
# 6-8 6.67
# 6-0 6.0
# 5-11 5.92
# 7-1 7.08
# 6-10 6.83
# 7-2 7.17
# 6-6 6.5
# 6-9 6.75
# 6-7 6.58
# 7-0 7.0
# 6-4 6.33
# 6-3 6.25
# 6-6 6.5
# 6-10 6.83
# 7-1 7.08
# 6-4 6.33
# 6-9 6.75
# 6-11 6.92
# 6-6 6.5
# 6-9 6.75
# 7-1 7.08
# 6-10 6.83
# 6-0 6.0
# 6-7 6.58
# 7-4 7.33
# 7-1 7.08
# 6-6 6.5
# 6-8 6.67
# 6-6 6.5
# 6-9 6.75
# 6-6 6.5
# 7-1 7.08
# 7-2 7.17
# 6-8 6.67
# 6-9 6.75
# 6-4 6.33
# 6-9 6.75
# 6-11 6.92
# 6-0 6.0
# 6-6 6.5
# 6-10 6.83
# 6-11 6.92
# 6-9 6.75
# 6-2 6.17
# 6-4 6.33
# 7-2 7.17
# 6-6 6.5
# 6-10 6.83
# 6-11 6.92
# 6-11 6.92
# 6-8 6.67
# 7-1 7.08
# 6-9 6.75
# 6-6 6.5
# 7-1 7.08
# 6-7 6.58
# 7-2 7.17
# 6-3 6.25
# 6-9 6.75
# 6-8 6.67
# 6-9 6.75
# 6-11 6.92
# 6-4 6.33
# 6-10 6.83
# 7-1 7.08
# 6-11 6.92
# 6-6 6.5
# 6-11 6.92
# 6-3 6.25
# 6-5 6.42
# 7-1 7.08
# 6-4 6.33
# 6-7 6.58
# 6-4 6.33
# 6-5 6.42
# 6-6 6.5
# 6-7 6.58
# 6-0 6.0
# 6-0 6.0
# 6-11 6.92
# 6-9 6.75
# 6-3 6.25
# 6-0 6.0
# 6-5 6.42
# 6-6 6.5
# 6-7 6.58
# 6-9 6.75
# 6-9 6.75
# 6-3 6.25
# 6-11 6.92
# 6-2 6.17
# 6-9 6.75
# 6-1 6.08
# 6-7 6.58
# 6-11 6.92
# 6-9 6.75
# 6-7 6.58
# 6-4 6.33
# 6-11 6.92
# 6-8 6.67
# 6-11 6.92
# 6-9 6.75
# 7-1 7.08
# 6-0 6.0
# 6-11 6.92
# 6-9 6.75
# 7-1 7.08
# 6-3 6.25
# 6-9 6.75
# 6-4 6.33
# 7-1 7.08
# 6-0 6.0
# 7-0 7.0
# 6-0 6.0
# 6-6 6.5
# 6-5 6.42
# 6-11 6.92
# 6-6 6.5
# 6-9 6.75
# 6-4 6.33
# 6-11 6.92
# 6-11 6.92
# 6-4 6.33
# 6-7 6.58
# 6-3 6.25
# 6-3 6.25
# 6-9 6.75
# 6-7 6.58
# 6-2 6.17
# 6-9 6.75
# 6-11 6.92
# 6-0 6.0
# 6-11 6.92
# 6-6 6.5
# 6-11 6.92
# 6-5 6.42
# 6-6 6.5
# 6-8 6.67
# 6-7 6.58
# 6-4 6.33
# 7-1 7.08
# 6-7 6.58
# 6-11 6.92
# 6-9 6.75
# 6-10 6.83
# 6-0 6.0
# 6-3 6.25
# 6-8 6.67
# 7-1 7.08
# 6-6 6.5
# 6-5 6.42
# 6-8 6.67
# 6-6 6.5
# 6-6 6.5
# 6-11 6.92
# 6-3 6.25
# 6-6 6.5
# 6-7 6.58
# 6-11 6.92
# 6-9 6.75
# 6-3 6.25
# 6-11 6.92
# 6-6 6.5
# 6-2 6.17
# 6-6 6.5
# 7-0 7.0
# 6-5 6.42
# 6-11 6.92
# 6-4 6.33
# 6-11 6.92
# 6-9 6.75
# 6-9 6.75
# 6-7 6.58
# 6-6 6.5
# 6-0 6.0
# 6-2 6.17
# 6-0 6.0
# 6-11 6.92
# 6-7 6.58
# 6-10 6.83
# 6-6 6.5
# 7-0 7.0
# 6-7 6.58
# 6-6 6.5
# 6-11 6.92
# 6-8 6.67
# 6-7 6.58
# 7-0 7.0
# 6-7 6.58
# 6-6 6.5
# 6-6 6.5
# 7-1 7.08
# 7-3 7.25
# 6-8 6.67
# 6-10 6.83
# 7-6 7.5
# 6-9 6.75
# 6-9 6.75
# 6-4 6.33
# 6-6 6.5
# 6-9 6.75
# 6-11 6.92
# 6-4 6.33
# 6-11 6.92
# 6-9 6.75
# 6-11 6.92
# 6-2 6.17
# 6-7 6.58
# 6-7 6.58
# 6-5 6.42
# 6-9 6.75
# 6-9 6.75
# 6-4 6.33
# 6-3 6.25
# 6-8 6.67
# 6-11 6.92
# 6-7 6.58
# 6-10 6.83
# 6-6 6.5
# 7-1 7.08
# 7-2 7.17
# 6-4 6.33
# 6-3 6.25
# 6-11 6.92
# 6-0 6.0
# 6-6 6.5
# 6-7 6.58
# 6-9 6.75
# 6-3 6.25
# 6-10 6.83
# 6-4 6.33
# 6-8 6.67
# 6-6 6.5
# 6-3 6.25
# 6-7 6.58
# 6-3 6.25
# 6-0 6.0
# 6-5 6.42
# 6-3 6.25
# 6-6 6.5
# 6-7 6.58
# 6-8 6.67
# 6-0 6.0
# 6-11 6.92
# 6-8 6.67
# 6-2 6.17
# 6-0 6.0
# 6-3 6.25
# 6-7 6.58
# 6-8 6.67
# 6-6 6.5
# 7-0 7.0
# 6-8 6.67
# 6-2 6.17
# 6-5 6.42
# 6-8 6.67
# 6-11 6.92
# 6-7 6.58
# 6-2 6.17
# 7-0 7.0
# 6-0 6.0
# 6-3 6.25
# 7-1 7.08
# 6-7 6.58
# 6-7 6.58
# 6-10 6.83
# 6-3 6.25
# 7-0 7.0
# 6-8 6.67
# 6-7 6.58
# 6-8 6.67
# 6-10 6.83
# 6-8 6.67
# 6-5 6.42
# 6-4 6.33
# 6-11 6.92
# 6-3 6.25
# 6-6 6.5
# 6-5 6.42
# 6-10 6.83
# 6-8 6.67
# 7-6 7.5
# 6-8 6.67
# 7-0 7.0
# 6-8 6.67
# 6-8 6.67
# 6-7 6.58
# 6-2 6.17
# 6-0 6.0
# 7-0 7.0
# 6-3 6.25
# 7-6 7.5
# 6-3 6.25
# 6-2 6.17
# 6-11 6.92
# 6-0 6.0
# 6-8 6.67
# 6-9 6.75
# 6-7 6.58
# 6-6 6.5
# 6-0 6.0
# 6-11 6.92
# 6-2 6.17
# 6-3 6.25
# 6-4 6.33
# 6-7 6.58
# 6-6 6.5
# 6-6 6.5
# 6-7 6.58
# 6-6 6.5
# 6-0 6.0
# 6-9 6.75
# 6-4 6.33
# 6-3 6.25
# 6-7 6.58
# 6-3 6.25
# 6-8 6.67
# 6-9 6.75
# 6-3 6.25
# 6-11 6.92
# 6-0 6.0
# 6-6 6.5
# 6-3 6.25
# 6-8 6.67
# 6-7 6.58
# 6-11 6.92
# 6-11 6.92
# 7-6 7.5
# 6-7 6.58
# 6-6 6.5
# 6-4 6.33
# 6-6 6.5
# 6-8 6.67
# 6-6 6.5
# 6-10 6.83
# 6-7 6.58
# 6-6 6.5
# 6-10 6.83
# 6-4 6.33
# 6-8 6.67
# 6-4 6.33
# 6-11 6.92
# 6-3 6.25
# 6-3 6.25
# 6-7 6.58
# 6-3 6.25
# 6-4 6.33
# 7-0 7.0
# 6-3 6.25
# 6-11 6.92
# 6-6 6.5
# 6-7 6.58
# 6-1 6.08
# 6-7 6.58
# 6-3 6.25
# 6-9 6.75
# 6-3 6.25
# 6-3 6.25
# 6-6 6.5
# 6-8 6.67
# 6-11 6.92
# 6-8 6.67
# 6-8 6.67
# 7-0 7.0
# 6-7 6.58
# 7-6 7.5
# 6-0 6.0
# 6-9 6.75
# 6-11 6.92
# 6-0 6.0
# 6-7 6.58
# 6-6 6.5
# 6-6 6.5
# 6-8 6.67
# 6-11 6.92
# 6-0 6.0
# 6-9 6.75
# 6-10 6.83
# 6-6 6.5
# 6-8 6.67
# 6-3 6.25
# 6-6 6.5
# 6-8 6.67
# 6-6 6.5
# 6-3 6.25
# 6-10 6.83
# 6-10 6.83
# 7-0 7.0
# 6-10 6.83
# 6-10 6.83
# 6-7 6.58
# 6-3 6.25
# 6-11 6.92
# 6-6 6.5
# 6-8 6.67
# 6-0 6.0
# 6-7 6.58
# 6-0 6.0
# 6-7 6.58
# 6-8 6.67
# 6-7 6.58
# 6-6 6.5
# 6-9 6.75
# 6-6 6.5
# 6-11 6.92
# 6-8 6.67
# 6-8 6.67
# 6-2 6.17
# 6-11 6.92
# 6-0 6.0
# 6-11 6.92
# 7-6 7.5
# 6-9 6.75
# 6-8 6.67
# 6-3 6.25
# 6-6 6.5
# 6-11 6.92
# 6-4 6.33
# 6-11 6.92
# 6-2 6.17
# 6-8 6.67
# 6-0 6.0
# 6-8 6.67
# 6-6 6.5
# 6-4 6.33
# 6-3 6.25
# 6-3 6.25
# 6-9 6.75
# 6-11 6.92
# 7-0 7.0
# 6-8 6.67
# 7-0 7.0
# 6-9 6.75
# 6-2 6.17
# 6-8 6.67
# 7-0 7.0
# 6-0 6.0
# 6-0 6.0
# 6-11 6.92
# 6-6 6.5
# 6-5 6.42
# 6-10 6.83
# 6-8 6.67
# 6-6 6.5
# 6-0 6.0
# 6-0 6.0
# 6-9 6.75
# 6-11 6.92
# 6-4 6.33
# 7-0 7.0
# 6-3 6.25
# 6-6 6.5
# 6-4 6.33
# 7-0 7.0
# 6-8 6.67
# 6-3 6.25
# 6-8 6.67
# 6-10 6.83
# 6-11 6.92
# 6-0 6.0
# 6-11 6.92
# 7-0 7.0
# 6-11 6.92
# 6-9 6.75
# 6-4 6.33
# 6-6 6.5
# 6-7 6.58
# 7-0 7.0
# 7-0 7.0
# 6-6 6.5
# 6-4 6.33
# 7-0 7.0
# 6-8 6.67
# 7-0 7.0
# 6-11 6.92
# 6-9 6.75
# 6-8 6.67
# 6-3 6.25
# 6-11 6.92
# 6-9 6.75
# 6-8 6.67
# 6-3 6.25
# 6-8 6.67
# 6-8 6.67
# 6-8 6.67
# 7-0 7.0
# 6-3 6.25
# 6-9 6.75
# 6-8 6.67
# 6-6 6.5
# 6-11 6.92
# 6-6 6.5
# 6-5 6.42
# 6-3 6.25
# 6-11 6.92
# 6-9 6.75
# 6-7 6.58
# 6-11 6.92
# 6-8 6.67
# 6-6 6.5
# 6-1 6.08
# 7-0 7.0
# 6-7 6.58
# 7-0 7.0
# 6-11 6.92
# 6-8 6.67
# 6-8 6.67
# 6-9 6.75
# 6-8 6.67
# 6-9 6.75
# 6-11 6.92
# 6-6 6.5
# 6-8 6.67
# 6-1 6.08
# 6-4 6.33
# 6-2 6.17
# 6-7 6.58
# 6-3 6.25
# 6-11 6.92
# 6-7 6.58
# 6-11 6.92
# 6-11 6.92
# 6-8 6.67
# 6-9 6.75
# 6-8 6.67
# 6-9 6.75
# 6-11 6.92
# 6-11 6.92
# 6-3 6.25
# 6-3 6.25
# 6-8 6.67
# 6-9 6.75
# 6-4 6.33
# 6-3 6.25
# 6-8 6.67
# 6-3 6.25
# 6-7 6.58
# 6-2 6.17
# 6-4 6.33
# 7-0 7.0
# 6-10 6.83
# 6-3 6.25
# 6-11 6.92
# 7-0 7.0
# 6-10 6.83
# 6-3 6.25
# 6-3 6.25
# 6-3 6.25
# 6-11 6.92
# 6-0 6.0
# 6-1 6.08
# 7-0 7.0
# 6-8 6.67
# 6-10 6.83
# 6-11 6.92
# 7-0 7.0
# 6-8 6.67
# 6-3 6.25
# 6-7 6.58
# 6-0 6.0
# 6-7 6.58
# 6-9 6.75
# 6-10 6.83
# 7-0 7.0
# 6-10 6.83
# 6-3 6.25
# 6-3 6.25
# 5-11 5.92
# 6-8 6.67
# 6-9 6.75
# 6-3 6.25
# 6-3 6.25
# 6-7 6.58
# 6-2 6.17
# 6-8 6.67
# 6-3 6.25
# 6-11 6.92
# 7-1 7.08
# 6-3 6.25
# 6-6 6.5
# 6-8 6.67
# 6-6 6.5
# 6-8 6.67
# 6-9 6.75
# 6-8 6.67
# 6-6 6.5
# 6-8 6.67
# 6-11 6.92
# 6-6 6.5
# 6-10 6.83
# 6-8 6.67
# 6-5 6.42
# 6-4 6.33
# 6-11 6.92
# 6-4 6.33
# 6-6 6.5
# 6-3 6.25
# 5-11 5.92
# 6-8 6.67
# 6-6 6.5
# 6-8 6.67
# 6-3 6.25
# 5-9 5.75
# 6-9 6.75
# 6-3 6.25
# 6-2 6.17
# 6-9 6.75
# 6-9 6.75
# 6-1 6.08
# 6-9 6.75
# 6-8 6.67
# 6-5 6.42
# 6-3 6.25
# 6-6 6.5
# 6-8 6.67
# 6-0 6.0
# 6-9 6.75
# 6-9 6.75
# 6-9 6.75
# 6-10 6.83
# 6-8 6.67
# 6-9 6.75
# 6-10 6.83
# 6-11 6.92
# 6-8 6.67
# 6-9 6.75
# 6-8 6.67
# 6-8 6.67
# 6-1 6.08
# 6-5 6.42
# 6-2 6.17
# 6-3 6.25
# 6-10 6.83
# 7-0 7.0
# 7-0 7.0
# 6-11 6.92
# 6-7 6.58
# 6-9 6.75
# 6-10 6.83
# 6-10 6.83
# 6-8 6.67
# 6-5 6.42
# 6-4 6.33
# 6-5 6.42
# 6-1 6.08
# 6-10 6.83
# 6-9 6.75
# 6-9 6.75
# 6-1 6.08
# 6-3 6.25
# 6-8 6.67
# 6-9 6.75
# 6-9 6.75
# 6-9 6.75
# 6-8 6.67
# 6-11 6.92
# 6-8 6.67
# 6-9 6.75
# 6-11 6.92
# 6-9 6.75
# 6-4 6.33
# 6-10 6.83
# 6-3 6.25
# 6-11 6.92
# 6-5 6.42
# 6-11 6.92
# 6-8 6.67
# 6-9 6.75
# 6-4 6.33
# 6-11 6.92
# 6-8 6.67
# 6-10 6.83
# 6-9 6.75
# 6-10 6.83
# 6-6 6.5
# 6-10 6.83
# 5-9 5.75
# 6-11 6.92
# 7-0 7.0
# 6-5 6.42
# 7-0 7.0
# 6-3 6.25
# 6-4 6.33
# 6-0 6.0
# 6-3 6.25
# 6-10 6.83
# 6-1 6.08
# 6-3 6.25
# 5-9 5.75
# 6-3 6.25
# 6-11 6.92
# 6-3 6.25
# 6-3 6.25
# 6-9 6.75
# 6-8 6.67
# 6-7 6.58
# 6-10 6.83
# 6-1 6.08
# 6-1 6.08
# 6-7 6.58
# 6-2 6.17
# 6-9 6.75
# 6-7 6.58
# 6-5 6.42
# 6-10 6.83
# 6-11 6.92
# 6-4 6.33
# 6-5 6.42
# 6-1 6.08
# 6-11 6.92
# 6-8 6.67
# 6-10 6.83
# 6-1 6.08
# 6-11 6.92
# 6-8 6.67
# 6-3 6.25
# 6-3 6.25
# 6-3 6.25
# 6-11 6.92
# 6-7 6.58
# 6-8 6.67
# 7-0 7.0
# 6-8 6.67
# 6-0 6.0
# 6-8 6.67
# 6-7 6.58
# 6-1 6.08
# 6-9 6.75
# 6-1 6.08
# 6-3 6.25
# 6-8 6.67
# 6-7 6.58
# 6-1 6.08
# 6-3 6.25
# 5-9 5.75
# 6-11 6.92
# 6-4 6.33
# 6-9 6.75
# 6-1 6.08
# 6-11 6.92
# 6-4 6.33
# 6-9 6.75
# 6-8 6.67
# 6-0 6.0
# 7-0 7.0
# 6-7 6.58
# 6-11 6.92
# 6-3 6.25
# 6-3 6.25
# 6-7 6.58
# 6-7 6.58
# 6-9 6.75
# 6-3 6.25
# 6-3 6.25
# 6-9 6.75
# 6-9 6.75
# 6-8 6.67
# 6-3 6.25
# 6-8 6.67
# 6-11 6.92
# 6-11 6.92
# 6-5 6.42
# 6-11 6.92
# 6-3 6.25
# 206cm 6.76
# 191cm 6.27
# 201cm 6.59
# 191cm 6.27
# 201cm 6.59
# 196cm 6.43
# 213cm 6.99
# 191cm 6.27
# 193cm 6.33
# 213cm 6.99
# 185cm 6.07
# 201cm 6.59
# 203cm 6.66
# 208cm 6.82
# 175cm 5.74
# 191cm 6.27
# 193cm 6.33
# 211cm 6.92
# 213cm 6.99
# 201cm 6.59
# 201cm 6.59
# 203cm 6.66
# 201cm 6.59
# 191cm 6.27
# 193cm 6.33
# 196cm 6.43
# 175cm 5.74
# 191cm 6.27
# 201cm 6.59
# 196cm 6.43
# 203cm 6.66
# 216cm 7.09
# 211cm 6.92
# 191cm 6.27
# 208cm 6.82
# 206cm 6.76
# 201cm 6.59
# 208cm 6.82
# 201cm 6.59
# 196cm 6.43
# 203cm 6.66
# 191cm 6.27
# 203cm 6.66
# 191cm 6.27
# 208cm 6.82
# 208cm 6.82
# 193cm 6.33
# 191cm 6.27
# 203cm 6.66
# 211cm 6.92
# 203cm 6.66
# 191cm 6.27
# 201cm 6.59
# 191cm 6.27
# 201cm 6.59
# 208cm 6.82
# 213cm 6.99
# 196cm 6.43
# 211cm 6.92
# 196cm 6.43
# 203cm 6.66
# 191cm 6.27
# 213cm 6.99
# 191cm 6.27
# 191cm 6.27
# 185cm 6.07
# 201cm 6.59
# 191cm 6.27
# 196cm 6.43
# 185cm 6.07
# 201cm 6.59
# 191cm 6.27
# 203cm 6.66
# 183cm 6.0
# 193cm 6.33
# 206cm 6.76
# 203cm 6.66
# 196cm 6.43
# 191cm 6.27
# 208cm 6.82
# 201cm 6.59
# 213cm 6.99
# 206cm 6.76
# 208cm 6.82
# 221cm 7.25
# 196cm 6.43
# 193cm 6.33
# 211cm 6.92
# 211cm 6.92
# 196cm 6.43

# %% [markdown]
# Check the results of the activity
# does the new height match the old height?

# %% [markdown]
# ### Reassign the new height to Height
# We might need inches for something so we will keep that column for now.

# %%
bbdf['Height'] = bbdf['nheight']
bbdf = bbdf.drop(['nheight'],axis=1)
#bbdf = bbdf.drop(['htype'],axis=1)
#bbdf = bbdf.drop(['wtype'],axis=1)
#bbdf = bbdf.drop(['h'],axis=1)

# %% [markdown]
# ### Convert the weight in a similar way.

# %%
bbdf[['weight','wtype']] = bbdf['Weight'].str.split('kg', expand=True)
#print (bbdf)

bbdf.weight[bbdf['wtype'].notnull()] = (bbdf['weight'].astype(float)*2.20462)
bbdf['weight'] = bbdf['weight'].astype(int)

#print(bbdf['weight'])
bbdf['Weight'] = bbdf['weight']
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### More Normalization:
# ### To a certain extent .. this could be called feature selection as well.
# ### Combining Classes to fit the objective can be helpful.
# ### Here we will go to the extreme for demonstration purposes
# #### The distribution of the FC and the GF classes should be factored into the other classes

# %%
pcounts = bbdf['Position'].value_counts()
print(pcounts)
# Out:
# G      178
# SG     164
# C      158
# PF     139
# F      125
# PG     120
# SF     119
# FC      83
# GF      47
# F-C      9
# G-F      3
# Name: Position, dtype: int64

# %% [markdown]
# ### Some of the position values can be combined for analysis

# %%
d = {'F-C':'F','G-F':'G','GF':'G', 'FC': 'F'}
bbdf = bbdf.replace(d)
e = {'SG': 'G', 'PF': 'F','PG':'G','SF':'F','FC':'F','GF':'F'}
bbdf['PClass'] = bbdf['Position']
bbdf['PClass'] = bbdf['PClass'].str.strip().replace(e)

pxcounts = bbdf['Position'].value_counts()
pccounts = bbdf['PClass'].value_counts()




pcnames = list(pccounts.index)
pxnames = list(pxcounts.index)
print(pccounts)
#print(pcnames)
print(pxcounts)
#print(pxnames)
# Out:
# G    512
# F    475
# C    158
# Name: PClass, dtype: int64
# G     228
# F     217
# SG    164
# C     158
# PF    139
# PG    120
# SF    119
# Name: Position, dtype: int64

# %% [markdown]
# ### the null values are the htype and wtype to signify where we converted data

# %%
bbdf.isnull().sum()
# Out:
# Age                     0
# Conference              0
# Date                    0
# Draft Year              0
# Height                  0
# Player                  0
# Position                0
# Seasons in league       0
# Team                    0
# Weight                  0
# Real_value              0
# Last-Name               0
# First-Name              0
# TeamName                0
# City                    0
# SSeason                 0
# inches                  0
# htype                1055
# feet                    0
# weight                  0
# wtype                1055
# PClass                  0
# dtype: int64

# %%
print(bbdf[:5])
# Out:
#    Age Conference          Date  Draft Year  Height                  Player  \
# 0   29       East  Apr 14, 1985        1978    6.42  Micheal Ray Richardson
# 1   23       West   Apr 7, 1985        1982    6.50             Derek Smith
# 2   28       West   Apr 1, 1985        1979    6.50             Calvin Natt
# 3   37       West  Mar 24, 1985        1969    7.17     Kareem Abdul-Jabbar
# 4   28       East  Mar 17, 1985        1978    6.75              Larry Bird
#
#   Position  Seasons in league                  Team  Weight   ...    \
# 0       PG                  6       New Jersey Nets     189   ...
# 1       SG                  2  Los Angeles Clippers     205   ...
# 2        F                  5        Denver Nuggets     220   ...
# 3        C                 15    Los Angeles Lakers     225   ...
# 4       SF                  5        Boston Celtics     220   ...
#
#     First-Name  TeamName         City SSeason inches  htype  feet weight  \
# 0  Micheal Ray      Nets   New Jersey    1985   77.0   None     6    189
# 1        Derek  Clippers  Los Angeles    1985   78.0   None     6    205
# 2       Calvin   Nuggets       Denver    1985   78.0   None     6    220
# 3       Kareem    Lakers  Los Angeles    1985   86.0   None     7    225
# 4        Larry   Celtics       Boston    1985   81.0   None     6    220
#
#   wtype  PClass
# 0  None       G
# 1  None       G
# 2  None       F
# 3  None       C
# 4  None       F
#
# [5 rows x 22 columns]

# %%
bbdf.shape
# Out:
# (1145, 22)

# %% [markdown]
# ## Check our Data Formats one more time
# #### spaces in column headers and indexes can be dangerous

# %%
bbdf = bbdf.rename(index=str, columns={"Draft Year": "DYear", "Seasons in league": "SIL"})

# %%
bbdf.dtypes
# Out:
# Age             int64
# Conference     object
# Date           object
# DYear           int64
# Height        float64
# Player         object
# Position       object
# SIL             int64
# Team           object
# Weight          int64
# Real_value    float64
# Last-Name      object
# First-Name     object
# TeamName       object
# City           object
# SSeason         int64
# inches        float64
# htype          object
# feet           object
# weight          int64
# wtype          object
# PClass         object
# dtype: object

# %% [markdown]
# ## Group the data by Player and Position so we can get some descriptive statistics
# .first gives the first record for each given search item

# %%
bbdfu = bbdf.groupby(['Player']).first()

#print(bbdfu)
bbdfug = bbdfu.groupby(['Position'])
#list(bbdfug)

bbdfugd = dict(tuple(bbdfu.groupby('Position')))
print(type(bbdfugd))
print(bbdfu['Position'].value_counts(),"\n")
print(bbdfu['PClass'].value_counts(),"\n")
print(bbdfu.shape)
# Out:
# <class 'dict'>
# G     60
# F     46
# C     39
# PF    35
# SG    34
# PG    33
# SF    27
# Name: Position, dtype: int64
#
# G    127
# F    108
# C     39
# Name: PClass, dtype: int64
#
# (274, 21)

# %% [markdown]
# ### Descriptive Statistics for
# ### Weight, Age, Height and Draft Year

# %%
print("\nWeight\n")

print("min ", bbdfu['weight'].min())
print("max ", bbdfu['weight'].max())
print("median ",bbdfu['weight'].median())
print("mode ",bbdfu['weight'].mode())
print("stddev ", bbdfu['weight'].std())

print("\nAge\n")

print("min ", bbdfu['Age'].min())
print("max ", bbdfu['Age'].max())
print("median ",bbdfu['Age'].median())
print("mode ",bbdfu['Age'].mode())
print("stddev ", bbdfu['Age'].std())

print("\nHeight\n")



print("min ", bbdfu['Height'].min())
print("max ", bbdfu['Height'].max())
print("median ",bbdfu['Height'].median())
print("mode ",bbdfu['Height'].mode())
print("stddev ", bbdfu['Height'].std())

print("\nDraft Year\n")

print("min ", bbdfu['DYear'].min())
print("max ", bbdfu['DYear'].max())
print("median ",bbdfu['DYear'].median())
print("mode ",bbdfu['DYear'].mode())
print("stddev ", bbdfu['DYear'].std())
# Out:
# Weight
#
# min  150
# max  325
# median  220.0
# mode  0    220
# dtype: int64
# stddev  29.409890047000665
#
# Age
#
# min  19
# max  37
# median  25.0
# mode  0    25
# dtype: int64
# stddev  3.0655542823781463
#
# Height
#
# min  5.75
# max  7.5
# median  6.58
# mode  0    6.58
# dtype: float64
# stddev  0.31376920010234105
#
# Draft Year
#
# min  1969
# max  2016
# median  1996.5
# mode  0    1996
# dtype: int64
# stddev  10.57175474281778

# %%
bbdfu.hist(column='DYear')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108545c18>]],
#       dtype=object)

# %%
bbdfu.loc[bbdfu['DYear'] == 1969]
# Out:
#                      Age Conference          Date  DYear  Height Position  \
# Player
# Kareem Abdul-Jabbar   37       West  Mar 24, 1985   1969    7.17        C
#
#                      SIL                Team  Weight  Real_value  ...    \
# Player                                                            ...
# Kareem Abdul-Jabbar   15  Los Angeles Lakers     225         1.0  ...
#
#                     First-Name TeamName         City SSeason  inches  htype  \
# Player
# Kareem Abdul-Jabbar     Kareem   Lakers  Los Angeles    1985    86.0   None
#
#                     feet weight  wtype PClass
# Player
# Kareem Abdul-Jabbar    7    225   None      C
#
# [1 rows x 21 columns]

# %%
bbdfu.loc[bbdfu['Weight']== 325]
# Out:
#                   Age Conference          Date  DYear  Height Position  SIL  \
# Player
# Shaquille O'Neal   20       East  Nov 15, 1992   1992    7.08        C    0
#
#                            Team  Weight  Real_value  ...   First-Name  \
# Player                                               ...
# Shaquille O'Neal  Orlando Magic     325         1.0  ...    Shaquille
#
#                  TeamName     City SSeason  inches  htype feet weight  wtype  \
# Player
# Shaquille O'Neal    Magic  Orlando    1993    85.0   None    7    325   None
#
#                  PClass
# Player
# Shaquille O'Neal      C
#
# [1 rows x 21 columns]

# %%
#ygroup = bbdf.groupby(['Season short', 'Position']).transform(np.mean)
pgroup = bbdf.groupby('Player').first()

#print(pgroup)
#list(pgroup)

# %% [markdown]
# ## The regression line suggests that NBA player weight is going up <b>
#     (about five pounds in 50 years)
#
# ### and the height is steady
# ### https://seaborn.pydata.org/generated/seaborn.regplot.html

# %%
sns.regplot( x="DYear", y="Weight", data=pgroup)
plot.show()
sns.regplot( x="DYear", y="Height", data=pgroup)

# %% [markdown]
# ### What does it look like when we separate by Position

# %% [markdown]
# ## Highlight Position to look at the progress of weight and height through the years

# %%
# library & dataset

 
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="DYear", y="Weight", data=pgroup, fit_reg=False, hue='Position')



# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="DYear", y="inches", data=pgroup, fit_reg=False, hue='Position')

# %%
cols = ['Weight','Height','PClass']
# Basic correlogram
sns.swarmplot(x=pgroup['Position'], y=pgroup['Weight'])
plt.show()
sns.swarmplot(x=pgroup['Position'], y=pgroup['Height'])

# %% [markdown]
# ### Use PClass to dial in some clarity

# %%
# library & dataset

 
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="DYear", y="Weight", data=pgroup, fit_reg=False, hue='PClass')



# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="DYear", y="inches", data=pgroup, fit_reg=False, hue='PClass')

# %%
cols = ['Weight','Height','PClass']
# Basic correlogram
sns.swarmplot(x=pgroup['PClass'], y=pgroup['Weight'])
plt.show()
sns.swarmplot(x=pgroup['PClass'], y=pgroup['Height'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(pgroup, test_size=0.4)

# %% [markdown]
# ### Use Height and Weight to predict Position/PClass

# %%
# Instantiate the classifier
gnbp = GaussianNB()
gnbpc = GaussianNB()
used_features =[
    "Weight",
    "Height",
    "DYear",
]

# %% [markdown]
# ### Build a model for Position and PClass using GaussianNB

# %%
gnbp.fit(
    X_train[used_features].values,
    X_train["Position"]
)


gnbpc.fit(
    X_train[used_features].values,
    X_train["PClass"]
)
y_predp = gnbp.predict(X_test[used_features])
y_predpc = gnbpc.predict(X_test[used_features])

# %% [markdown]
# ### Check the accuracy of the model against the test set

# %%
print("Number of mislabeled points out of a total {} points : {}, performance {:05.2f}%"
      .format(
          X_test.shape[0],
          (X_test["Position"] != y_predp).sum(),
          100*(1-(X_test["Position"] != y_predp).sum()/X_test.shape[0])
))

print("Number of mislabeled points out of a total {} points : {}, performance {:05.2f}%"
      .format(
          X_test.shape[0],
          (X_test["PClass"] != y_predpc).sum(),
          100*(1-(X_test["PClass"] != y_predpc).sum()/X_test.shape[0])
))


print("")
# Out:
# Number of mislabeled points out of a total 110 points : 45, performance 59.09%
# Number of mislabeled points out of a total 110 points : 16, performance 85.45%

# %% [markdown]
# ## Build a Confusion Matrix to understand where the model slipped

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz
def plot_confusion_matrix(cm, classes,
                          title='x',
                          cmap=plt.cm.Blues):
    
 #   print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnc_matrix = confusion_matrix(X_test["PClass"], y_predpc)
np.set_printoptions(precision=2)

# Compute confusion matrix
cns_matrix = confusion_matrix(X_test["Position"], y_predp)
np.set_printoptions(precision=2)

# Plot 
plt.figure()
plot_confusion_matrix(cns_matrix, classes=pxnames,
                      title='Complex Class CM')


plt.show()

# Plot 
plt.figure()
plot_confusion_matrix(cnc_matrix, classes=pcnames,
                      title='Simple Class CM')


plt.show()

# %% [markdown]
# ### did we get through that in < 10min

# %% [markdown]
# Sensitivity (Recall or True positive rate)
# Specificity (True negative rate)
# Correlation coefficient and F-score

# %%
xtest = X_test["Position"]
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(xtest, y_predp, labels=pxnames)
# Out:
# (array([0.58, 0.56, 0.5 , 0.67, 0.75, 0.77, 0.42]),
#  array([0.71, 0.83, 0.46, 0.73, 0.3 , 0.59, 0.5 ]),
#  array([0.64, 0.67, 0.48, 0.7 , 0.43, 0.67, 0.45]),
#  array([21, 18, 13, 11, 20, 17, 10]))
