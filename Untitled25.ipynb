# %%
from nltk.tokenize import TreebankWordTokenizer
import json
import nltk
import os, sys, json, argparse
import pandas as pd
import numpy as np
import nltk
import re
import os
import codecs
from sklearn import feature_extraction
import mpld3
from string import punctuation
import matplotlib.pyplot as plt

import urllib.request, html5lib
from bs4 import BeautifulSoup, Tag, UnicodeDammit

# %%
SWdf = pd.read_csv('NLPout.csv')
SWdf
# Out:
#                            char  \
# 0                      THREEPIO
# 1                      THREEPIO
# 2                      THREEPIO
# 3                      THREEPIO
# 4                      THREEPIO
# 5                          LUKE
# 6                      THREEPIO
# 7                      THREEPIO
# 8                      THREEPIO
# 9                      THREEPIO
# 10             IMPERIAL OFFICER
# 11                        VADER
# 12                        VADER
# 13                REBEL OFFICER
# 14                        VADER
# 15                        VADER
# 16                      TROOPER
# 17                      TROOPER
# 18                     THREEPIO
# 19                     THREEPIO
# 20                     THREEPIO
# 21                     THREEPIO
# 22                  CHIEF PILOT
# 23                      CAPTAIN
# 24                     THREEPIO
# 25                     THREEPIO
# 26                        WOMAN
# 27                        FIXER
# ...

# %%
doc = dict(zip(SWdf['phrase'],SWdf['char']))

# %%
Ccount=SWdf.groupby('char').count()
plt.bar(Ccount.index.values, Ccount['phrase'])
plt.xlabel('char')
plt.ylabel('record')
plt.show()

# %%
chars = chars = [ 'LEIA', 'BEN','LUKE','HAN','TROOPER','VADER','WEDGE','THREEPIO','TARKIN','RED LEADER','OFFICER','JABBA','BIGGS']

Tdf = SWdf.loc[SWdf['char'].isin(chars)]

X=Tdf['char'].values 
yw=Tdf['word'].values
yp=Tdf['phrase'].values

# %%
Ccount=Tdf.groupby('char').count()
plt.bar(Ccount.index.values, Ccount['phrase'])
plt.xlabel('char')
plt.ylabel('record')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, Tdf['char'], test_size=0.3, random_state=1)

# %%
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features
# Out:
# <588x1395 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3053 stored elements in Compressed Sparse Row format>

# %%
featuresets = [(find_features(rev), category) for (rev, category) in documents]

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
text_counts= cv.fit_transform(Tdf['phrase'])
