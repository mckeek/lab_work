# %%
import pandas as pd
import numpy as np
import seaborn as sns
from pandas import Series
from pandas import DataFrame as df
from scipy.stats import trim_mean, kurtosis
from scipy.stats.mstats import mode, gmean, hmean

#dfTB = pd.read_csv("/Users/kenmckee/Desktop/GS/SP182/AA/Lab2.csv")
#series = Series.from_csv("/Users/kenmckee/Desktop/GS/SP182/AA/HW1/Zip_Zhvi_SingleFamilyResidence")
#print(dfTB.describe())
#list(series.columns.values)
#print(dfTB.head())


dates = pd.date_range(start='1/1/1997', periods=204, freq='M')

datex = pd.date_range(start='1/1/1997', periods=207, freq='M')



#print(dates)
#print(dates.shape)

#print(gbState.City.unique())

# %%
#get the arkansas data 
ARdata = dfTB.loc[dfTB['State'] == "FL"]

#Brev = dfTB.loc[dfTB['CountyName'] == "Brevard"]

#ARdata = FLdata.drop(['Unnamed: 0'], axis=1)

#set it up for graph
A1a  = ARdata.loc[ARdata['RegionName'] == 32951]




#print(A1a.describe())
A1b = A1a.groupby(['RegionName'])
A1c = A1b.mean()
A1d = A1c.loc['1997-01':'2014-03']
A1e = A1c.T
A1eTS = A1e.drop(A1e.index[[0,1,2,3]]).reset_index()
AleTSx = DataFrame(A1eTS)
AleTSy = AleTSx.iloc[9:216]


AvgHPLR = AleTSy


#print(AvgHPLR)

# %%
#print(Brev)

# %%
ts = pd.Series(datex)
#ty = pd.Series(AleTSy).reset_index()
t1 = AleTSy[32951].reset_index()
t2 = t1[32951]
#print(t2)

tz = pd.concat([ts, t2], axis=1)
tz.columns = ['date','avgHomePrice']

tz.index = tz['date']
del tz['date']
#print(tz)

# %%
#change this after you get your data 
#there should be a function built here but i dont know how to do that yet. 

#LRts = tz
#HSts = tz
#FVts = tz 
#SEts =tz

#ORts = tz
#TAts = tz
#KWts = tz
#BRts = tz
#BRCts = tz

#BRCf = tz

#ts32935 = tz
#ts32931 = tz
#ts32951 = tz

#Write to a CSV if you need to. 
BRCts.to_csv('BRCts.csv',sep=",")

#print(ts32951)
ts32935.to_csv('ts32935.csv')
ts32931.to_csv('ts32931.csv')
ts32951.to_csv('ts32951.csv')
#graph it
len(A1e)
BRCts.plot()
plt.title('Brevard Cities')
pyplot.show()

# %%
#graph it
len(A1e)
LRts.plot()
plt.title('Little Rock')
plt.grid(True)
pyplot.show()

len(A1e)
HSts.plot()
plt.title('Hot Springs')
plt.grid(True)
pyplot.show()

#graph it
len(A1e)
FVts.plot()
plt.title('Fayetteville')
plt.grid(True)
pyplot.show()

#graph it
len(A1e)
SEts.plot()
plt.title('Searcy')
plt.grid(True)
pyplot.show()

# %%
#LRts.describe()
#HSts.describe()
#FVts.describe()
SEts.describe()
# Out:
#         avgHomePrice
# count     204.000000
# mean    94566.049020
# std     16365.086426
# min     69356.000000
# 25%     77684.750000
# 50%     96792.500000
# 75%    109907.250000
# max    120719.000000

# %%
#graph it
len(A1e)
ORts.plot()
plt.title('Orlando')
pyplot.show()

#graph it
len(A1e)
TAts.plot()
plt.title('Tampa')
pyplot.show()

#graph it
len(A1e)
KWts.plot()
plt.title('Key West')
pyplot.show()

#graph it
len(A1e)
BRts.plot()
plt.title('Brevard County')
pyplot.show()

# %%
#Do it again for Florida

FLdata = dfTB.loc[dfTB['State'] == "FL"]
FLdata = FLdata.drop(['Unnamed: 0'], axis=1)

#gbCounty = FLdata.groupby(['CountyName'])
#print(FLdata.CountyName.unique())
#datax['Date'] = pd.to_datetime(datax['Date'])
FLOrl  = FLdata.loc[FLdata['City'] == "Orlando"]
#print(FLOrl)
FLOrlx = FLOrl.groupby(['City'])
FLOrlA  = FLOrlx.agg(['mean'])
FLOrlAx = FLOrlA.loc[:,'1997-01':'2013-12']
FLOrlAxt = FLOrlAx.T


FLTA   = FLdata.loc[FLdata['City'] == "Tampa"]
#print(FLTA)
FLTAx = FLTA.groupby(['City'])
FLTAA = FLTAx.agg(['mean'])
FLTAAx = FLTAA.loc[:,'1997-01':'2013-12']
FLTAAxt = FLTAAx.T
#print(FLTAAxt)


FLKW   = FLdata.loc[FLdata['City'] == "Key West"]
FLKWx = FLKW.groupby(['City'])
FLKWA   = FLKWx.agg(['mean'])
FLKWAx   = FLKWA.loc[:,'1997-01':'2013-12']
FLKWAxt = FLKWAx.T


CFLBrev = FLdata.loc[FLdata['CountyName'] == "Brevard"]
CFLBrevx = CFLBrev.groupby(['CountyName'])
CFLBrevA = CFLBrevx.agg(['mean'])
CFLBrevAx = CFLBrevA.loc[:,'1997-01':'2013-12']
CFLBrevAxt = CFLBrevAx.T

#print(CFLBrevAxt)

FLBrev = FLdata.loc[FLdata['CountyName'] == "Brevard"]
FLBrevx = FLBrev.groupby(['City'])
FLBrevA = FLBrevx.agg(['mean'])
FLBrevAx = FLBrevA.loc[:,'1997-01':'2013-12']
FLBrevAxt = FLBrevAx.T


#gbAggregatex = gbAggregate.sum()
#wksales = gbAggregatex['Weekly_Sales']
#print(gbAggregatex.values)
#print(wksales.index)
#gbCity = FLOrl.groupby(['City'])
#gbZip = FLBrev.groupby(['RegionName'])
#gbZipAvg = gbZip.agg(['mean'])
#FLOrlx = FLOrl.groupby(['City'])
#FLTAx.agg(['mean'])
#print(gbZipAvg.head)
#ZipMed = gbZip.agg('Med')
#ZipAvg = gbZip.agg(['Avg'])
#geZipTS = gbZipAvg.loc[:, ]
#print(ZipAvg)
#print(FLBrev.RegionName.unique())

# %%
from matplotlib import pyplot
from matplotlib import pylab
from matplotlib.font_manager import FontProperties

#len(FLOrlAxt)
#FLOrlAxt.plot()
#pyplot.show()


#len(FLTAAxt)
#FLTAAxt.plot()
#pyplot.show()
#pylab.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)
#pyplot.show()

len(FLKWAxt)
FLKWAxt.plot()
pyplot.show()

len(CFLBrevAx)
CFLBrevAxt.plot()
pyplot.show()
# Out:
# City          Cape Canaveral     Cocoa  Cocoa Beach  Grant-Valkaria   Malabar  \
# 1997-01 mean         77909.0   71071.5     130948.0             NaN  103807.0
# 1997-02 mean         78261.0   70983.0     131346.0             NaN  104281.0
# 1997-03 mean         78342.0   69635.0     131698.0             NaN  103545.0
# 1997-04 mean         78520.0   68991.5     132268.0             NaN  101519.0
# 1997-05 mean         79105.0   69268.5     132819.0             NaN   99805.0
# 1997-06 mean         79653.0   69160.0     132971.0             NaN   98701.0
# 1997-07 mean         80083.0   68972.0     132759.0             NaN   98882.0
# 1997-08 mean         80267.0   69023.5     132615.0             NaN   99669.0
# 1997-09 mean         80458.0   69184.0     132721.0             NaN  100225.0
# 1997-10 mean         80541.0   69481.5     133061.0             NaN  100770.0
# 1997-11 mean         80733.0   70281.0     133557.0             NaN  101997.0
# ...

# %%
len(FLBrevAxt)
FLBrevAxt.plot()
plt.grid(True)
pylab.legend(loc=9, bbox_to_anchor=(0.5, -0.1), ncol=2)
pyplot.show()

print(FLBrevAxt)
# Out:
# City          Cape Canaveral     Cocoa  Cocoa Beach  Grant-Valkaria   Malabar  \
# 1997-01 mean         77909.0   71071.5     130948.0             NaN  103807.0
# 1997-02 mean         78261.0   70983.0     131346.0             NaN  104281.0
# 1997-03 mean         78342.0   69635.0     131698.0             NaN  103545.0
# 1997-04 mean         78520.0   68991.5     132268.0             NaN  101519.0
# 1997-05 mean         79105.0   69268.5     132819.0             NaN   99805.0
# 1997-06 mean         79653.0   69160.0     132971.0             NaN   98701.0
# 1997-07 mean         80083.0   68972.0     132759.0             NaN   98882.0
# 1997-08 mean         80267.0   69023.5     132615.0             NaN   99669.0
# 1997-09 mean         80458.0   69184.0     132721.0             NaN  100225.0
# 1997-10 mean         80541.0   69481.5     133061.0             NaN  100770.0
# 1997-11 mean         80733.0   70281.0     133557.0             NaN  101997.0
# ...

# %%
#The baseline prediction for time series forecasting is called the naive forecast, or persistence.

# %%
from statsmodels.tsa.stattools import adfuller
#ts32935 = tz
#ts32931 = tz
#ts32951 = tz
# create a differenced series
def difference(dataset, interval=3):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return Series(diff)
 
X = ts32951.avgHomePrice
X = X.astype('float32')
# difference data
months_in_year = 12
stationary = difference(X, months_in_year)
stationary.index = ts32951.index[months_in_year:]
# check if stationary
result = adfuller(stationary)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# save
stationary.to_csv('stationary.csv')
# plot
stationary.plot()
plt.xlabel('Housing Prices 1997-2013')
plt.ylabel('Dollars')
plt.title('ZIP 32935 Housing')
plt.grid(True)
pyplot.show()
# Out:
# ADF Statistic: -2.392892
# p-value: 0.143753
# Critical Values:
# 	1%: -3.467
# 	5%: -2.878
# 	10%: -2.575

# %%
# invert differenced value
ts32935d = ts32935.diff(3)
ts32935d = ts32935d[3:]

print(ts32935d)
# Out:
#             avgHomePrice
# date
# 1997-04-30        -501.0
# 1997-05-31        -849.0
# 1997-06-30        -698.0
# 1997-07-31        -284.0
# 1997-08-31         188.0
# 1997-09-30         644.0
# 1997-10-31        1026.0
# 1997-11-30        1190.0
# 1997-12-31        1201.0
# 1998-01-31        1080.0
# 1998-02-28         800.0
# 1998-03-31         661.0
# 1998-04-30         710.0
# 1998-05-31         854.0
# 1998-06-30         926.0
# 1998-07-31        1021.0
# 1998-08-31        1100.0
# 1998-09-30        1136.0
# 1998-10-31         896.0
# 1998-11-30         675.0
# 1998-12-31         459.0
# 1999-01-31         614.0
# 1999-02-28         902.0
# 1999-03-31        1084.0
# 1999-04-30         899.0
# 1999-05-31         683.0
# 1999-06-30         503.0
# 1999-07-31         467.0
# 1999-08-31         376.0
# 1999-09-30         247.0
# ...                  ...
# 2011-10-31         965.0
# 2011-11-30         873.0
# 2011-12-31         942.0
# 2012-01-31         689.0
# ...

# %%
#ts32935 = tz
#ts32931 = tz
#ts32951 = tz
# create a differenced series

differenced.to_csv('seasonally_adjusted.csv')

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf



plot_acf(ts32935d.avgHomePrice, ax=pyplot.gca())
pyplot.show()

#pyplot.subplot(212)

plot_pacf(ts32935d.avgHomePrice, ax=pyplot.gca())
pyplot.show()

# %%
#https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/

from pandas import read_csv
from pandas import datetime
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

#First, we fit an ARIMA(5,1,0) model. This sets the lag value to 5 for autoregression, uses a difference order of 1 to make the time series stationary, and uses a moving average model of 0.

#When fitting the model, a lot of debug information is provided about the fit of the linear regression model. We can turn this off by setting the disp argument to 0.

model = ARIMA(ts32935d, order=(1,1,0))
model_fit = model.fit(disp=1)
print(model_fit.summary())
# plot residual errors
residuals = DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
#                              ARIMA Model Results
# ...

# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
 
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
 

X = ts32935d.avgHomePrice
size = int(len(X) * 0.66)
train, test = X[0:size], X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(5,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# plot
pyplot.plot(test)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:646: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:650: FutureWarning: Conversion of the second argument of issubdtype from `complex` to `np.complexfloating` is deprecated. In future, it will be treated as `np.complex128 == np.dtype(complex).type`.
#   elif issubdtype(paramsdtype, complex):
# /anaconda3/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py:577: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if issubdtype(paramsdtype, float):
# predicted=-7397.501650, expected=-7394.000000
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

num_plots = 20

# Have a look at the colormaps here and decide which one you'd like:
# http://matplotlib.org/1.2.1/examples/pylab_examples/show_colormaps.html
colormap = plt.cm.gist_ncar
plt.gca().set_color_cycle([colormap(i) for i in np.linspace(0, 0.9, num_plots)])

# Plot several different functions...
x = np.arange(10)
labels = []
for i in range(1, num_plots + 1):
    plt.plot(x, i * x + 5 * i)
    labels.append(r'$y = %ix + %i$' % (i, 5*i))

# I'm basically just demonstrating several different legend options here...
plt.legend(labels, ncol=4, loc='upper center', 
           bbox_to_anchor=[0.5, 1.1], 
           columnspacing=1.0, labelspacing=0.0,
           handletextpad=0.0, handlelength=1.5,
           fancybox=True, shadow=True)

plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
